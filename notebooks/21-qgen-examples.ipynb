# %% [markdown]
# ## Question generation: example prompt and question summary

# %%
from pprint import pprint

import pandas as pd

from info_salience import qgen

# %%
from info_salience.llm import LitellmGenerator

llm = LitellmGenerator(
    "gpt-4o-2024-08-06",
    caching=True,
    report_costs=True,
    disk_cache_dir=f".litellm_cache",
)

# %%
df_summaries = pd.read_json('../output/cs-cl/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json')

# %%
prompts = qgen.get_prompts(df_summaries, 'cs-cl', batch_size=5)
print(prompts[1][0]['content'])

response = llm.generate([prompts[1]])[0][0]
response = qgen.parse_response(response)
for length, qa_pairs in response.items():
    for qa_pair in qa_pairs:
        print('Q:', qa_pair['question'])
        print('A:', qa_pair['example_answer'])
        print()
# Out:
# Your task is to analyze summaries of different lengths within a given genre. Your goal is to create question-answer pairs that capture the essence of information typically included in various summary lengths. Below is the dataset where each document was summarized in 5 different lengths.
#
# # Dataset
#
# ## Document 1
#
# ### Summary 10 words
# Benchmarking initiatives evaluate language and time series model performance.
#
# ### Summary 20 words
# Benchmarking initiatives evaluate language models and time series prediction models for various tasks and challenges.
#
# ### Summary 50 words
# The document discusses benchmarking initiatives in NLP, time series analysis, and multi-task learning. It highlights GLUE, SuperGLUE, and SQuAD benchmarks for NLP, M3 and M4 competitions for time series forecasting, and multi-task learning techniques for improving model performance and generalization on multiple tasks.
#
# ### Summary 100 words
# The document discusses benchmarking initiatives in Natural Language Processing (NLP) and Time Series Analysis. GLUE and SuperGLUE benchmarks evaluate language models' performance on various tasks, while M3 and M4 competitions assess time series forecasting models. Time series anomaly detection is also a focus area, with benchmark datasets from Yahoo, Numenta, NASA, and Pei's Lab. Multi-task learning is a technique that trains models on multiple related tasks to improve performance and generalization, used in NLP and time series forecasting to leverage shared knowledge and handle missing values, anomalies, or noise in data.
#
# ### Summary 200 words
# The document discusses various benchmarking initiatives in the fields of Natural Language Processing (NLP) and Time Series Analysis. In NLP, the General Language Understanding Evaluation (GLUE) and SuperGLUE benchmarks are used to evaluate language models' performance on tasks such as sentiment analysis, textual entailment, and semantic similarity. These benchmarks assess models' adaptability to unseen data and provide a comprehensive evaluation of their capabilities. In Time Series Analysis, datasets such as M3 and M4 are used to evaluate prediction models, while datasets like ETTm2 and ECL cover various domains. Multi-task learning is a technique that trains a model on multiple related tasks to improve performance and generalization. It is used in NLP to leverage shared knowledge across tasks and in Time Series Analysis to handle missing values, anomalies, and noise. Researchers use multi-task learning to improve time series forecasting and handle complex data. The use of benchmarking initiatives and multi-task learning enables a clearer understanding of progress in these fields and fosters more accurate assessments of model performance.
#
# ## Document 2
#
# ### Summary 10 words
# LLMs improve mathematical reasoning with self-correction and fine-tuning methods.
#
# ### Summary 20 words
# LLMs for mathematical reasoning task face challenges, proposed approach incorporates iterative self-correction process for accurate results generation.
#
# ### Summary 50 words
# Mathematical reasoning is a challenging task for LLMs. Existing methods include prompting, pretraining, and finetuning. A new method, Chain of Self-Correction (CoSC), incorporates an iterative self-correction process into dataset generation, improving accuracy and effectiveness in solving mathematical problems.
#
# ### Summary 100 words
# Mathematical reasoning is a challenging task for Large Language Models (LLMs). Existing methods can be categorized into prompting, pretraining, and finetuning approaches. A new method, Chain of Self-Correction (CoSC), is proposed, which incorporates an iterative self-correction process into dataset generation. This method differs from existing self-correction techniques, which either rely on prompting or fine-tuning methods. CoSC models mathematical reasoning as a multi-round procedure during training and conducts verification in a step-by-step manner, improving the verification process. CoSC outperforms existing methods on challenging mathematical problem tasks, demonstrating its effectiveness.
#
# ### Summary 200 words
# Mathematical reasoning is a challenging task for Large Language Models (LLMs) that requires understanding mathematical concepts, computation, and multi-round reasoning. Existing methods can be categorized into three types: prompting, pretraining, and finetuning. Prompting methods utilize well-crafted prompts to extract LLMs' inherent mathematical reasoning skills without parameter updates. Pretraining methods pre-train LLMs on large-scale corpora containing mathematical problems. Finetuning methods refine LLMs' mathematical reasoning capabilities through targeted training. Recent studies have attempted to enable LLMs to perform self-correction by either prompting or fine-tuning methods. However, existing self-correction research can be broadly classified into two categories: prompt-based methods and SFT-based methods. Our proposed Chain of Self-Correction (CoSC) method embeds a chain of self-correction as an inherent capability in LLMs through parameter fine-tuning, modeling mathematical reasoning as a multi-round procedure during the training stage. Our method conducts verification in a step-by-step manner, significantly improving the verification process in self-correction.
#
# ## Document 3
#
# ### Summary 10 words
# Continual learning in language models improves knowledge and instruction-following capabilities.
#
# ### Summary 20 words
# Continual learning and model merging techniques improve large language models by acquiring new knowledge and instruction-following capabilities.
#
# ### Summary 50 words
# Continual learning is a technique for updating existing machine learning models with new information, allowing them to adapt to new data while preserving prior knowledge. Model merging techniques, such as Task Arithmetic, can combine capabilities and generalize to new skills in large language models.
#
# ### Summary 100 words
# Continual learning is a technique used to update existing machine learning models with new information, allowing them to adapt to new data while preserving prior knowledge. Researchers have applied continuous pre-training in large language models to acquire new skills and languages. Model merging is another technique that combines the capabilities of specialized fine-tuned models to generalize to new skills. In this study, Task Arithmetic is employed to extract instruction residual, but the impact of different merging techniques is not explored. The effectiveness of continuous pre-training and model merging for acquiring new knowledge and instruction-following capabilities is not fully understood.
#
# ### Summary 200 words
# Continual learning is a technique used to update existing machine learning models with new information and trends, allowing language models to adapt to new data while preserving prior knowledge. This technique has been applied in large language models (LLMs) to acquire new skills, domains, and languages. However, the reasons behind the effectiveness of continuous pre-training followed by instruction fine-tuning for acquiring new knowledge and instruction-following capabilities in LLMs have not been thoroughly explored. Model merging is another technique used to combine the capabilities of specialized fine-tuned models to generalize to new skills. Techniques such as Task Arithmetic, TIES, and Model Breadcrumbs have been explored for merging models. In this study, Task Arithmetic is employed to extract the instruction residual. The impact of different model merging techniques on the transfer of instruction-following capabilities is beyond the scope of this study. The goal is to understand the effectiveness of continuous pre-training and model merging in acquiring new knowledge and instruction-following capabilities in LLMs.
#
# ## Document 4
#
# ### Summary 10 words
# LLMs used for data augmentation with various selection strategies explored.
#
# ### Summary 20 words
# LLMs are used for data augmentation, with few-shot learning outperforming zero-shot methods in various tasks and applications.
#
# ### Summary 50 words
# Recent studies have used LLMs for data augmentation, leveraging their ability to produce diverse texts. Few-shot learning approaches using LLMs have shown better performance than zero-shot methods, but the effects of sample selection strategies are under-explored, with random selection being common.
#
# ### Summary 100 words
# Large Language Models (LLMs) like GPT-4 and Llama are being used as data augmentation tools to produce diverse texts. They are used for tasks such as automated scoring, low-resource language generation, sentiment analysis, hate speech detection, and health symptom classifications. Recent studies have used few-shot learning by supplying LLMs with examples from the dataset in prompts. However, the effects of sample selection strategies are under-explored, with most studies using random selection. Investigating various sample selection strategies is necessary to improve the performance of LLM-based augmentation methods.
#
# ### Summary 200 words
# Large language models (LLMs) such as GPT-4 and Llama have been used as data augmentation tools, leveraging their ability to produce diverse texts. They are typically used for paraphrasing, but can also be used to create semantically new samples. LLM-based augmentation has been applied to various tasks such as automated scoring, low-resource language generation, sentiment analysis, hate speech detection, news classification, content recommendation, and health symptoms classifications. Recent studies have used few-shot learning, where the LLM is supplied with examples from the dataset in the prompts, to improve performance. However, the effects of various sample selection strategies are under-explored, with most studies selecting samples randomly. A few studies have explored human-inspired sample selection strategies, and found that they can improve performance. The investigation of various sample selection strategies for LLM-based augmentation methods is lacking, despite their potential to significantly alter the performance of LLMs.
#
# ## Document 5
#
# ### Summary 10 words
# Agentic workflows and automated optimization for LLM applications and tasks.
#
# ### Summary 20 words
# Agentic workflow and autonomous agents represent two paradigms of LLM application with distinct problem-solving approaches.
#
# ### Summary 50 words
# Agentic workflow and autonomous agents are two distinct paradigms of LLM application, with agentic workflows offering higher potential for automated construction through existing human domain experience and iterative refinement. Automated workflow optimization aims to optimize entire workflow structures for fully automated generation.
#
# ### Summary 100 words
# Agentic workflow and autonomous agents are two distinct paradigms of LLM application. Agentic workflows can be categorized into general and domain-specific types, emphasizing universal problem-solving approaches or domain-specific problems. Automated agentic optimization aims to automate the design of agentic workflows, categorized into prompt optimization, hyperparameter optimization, and automated workflow optimization. Recent works explore diverse representations and methods, but are limited in generalization and often require human effort. AFlow introduces a more fundamental structure called named node and a specially designed MCTS algorithm for efficient workflow discovery.
#
# ### Summary 200 words
# Agentic workflow and autonomous agents are two distinct paradigms of Large Language Model (LLM) application. Agentic workflow completes tasks statically through predefined processes, while autonomous agents solve problems dynamically through flexible decision-making. Agentic workflows can be categorized into general and domain-specific types, with the latter focusing on solving domain-specific problems. Automated agentic optimization aims to automate the design of agentic workflows, categorized into three types: prompt optimization, hyperparameter optimization, and automated workflow optimization. Automated workflow optimization is the most promising approach, which optimizes entire workflow structures for fully automated generation. Recent works explore diverse representations and methods, including GPTSwarm and ADAS. AFlow is a novel approach that uses code to represent workflows with a more fundamental structure called named nodes, allowing for more detailed workflow representation and employing a specially designed MCTS algorithm for efficient discovery of effective workflows. AFlow has the potential to automate the design of agentic workflows, offering a more efficient and effective solution.
#
#
# # Genre
# The genre of the documents: Related work section in NLP papers.
#
# # Task
# Each text in the dataset has been summarized in 5 different lengths (in 10, 20, 50, 100, and 200 words). Your task is to analyze the summaries and identify the types of information typically included at each summary length. To do this, please proceed as follows:
#
# 1. Carefully read the summaries, paying attion to what information is included or omitted.
# 2. For each summary length, create a set of question-answer pairs that represent typical information included at this length. The questions should be general enough to apply to many documents in this genre, while the answers will naturally be different across documents.
#
# Important guidelines:
# - Ensure that your questions are relevant to the genre and capture information that would be commonly found in texts of this type.
# - It is really important that the questions are answerable with most documents in this genre, not just with the ones presented here! To this end, state a prototypical answer to each question.
# - The questions should be unique to each length. That means, do not repeat a question if it is already sufficiently covered at the shorter length.
# - Start with question words (What, How, Why, Which) rather than 'Can you'
# - Make the topic the grammatical subject of a question.
# - Keep the questions concise and focused.
# - Create at least 3-5 questions for each summary length.
#
# Structure your response as a valid json object with the following format:
#
# {
#     "questions_10_words": [
#         {
#             "question": "",
#             "example_answer": "",
#         }
#     ],
#     "questions_20_words": [
#         {
#             "question": "",
#             "example_answer": "",
#         }
#     ],
#     "questions_50_words": [
#         {
#             "question": "",
#             "example_answer": "",
#         }
#     ],
#     "questions_100_words": [
#         {
#             "question": "",
#             "example_answer": "",
#         }
#     ],
#     "questions_200_words": [
#         {
#             "question": "",
#             "example_answer": "",
#         }
#     ]
# }
# Batch cost: $0.0136
# Q: What is the primary focus of the study?
# A: Benchmarking initiatives.
#
# Q: Which method or model is highlighted?
# A: LLMs used for data augmentation.
#
# Q: What outcome or improvement is discussed?
# A: Improves mathematical reasoning.
#
# Q: What specific task or problem is addressed?
# A: Mathematical reasoning task.
#
# Q: What general approach or method is proposed?
# A: Agentic workflow and autonomous agents for LLM applications.
#
# Q: What are the key challenges or issues mentioned?
# A: Challenges in mathematical reasoning and iterative self-correction.
#
# Q: What are the main techniques or strategies explored in the study?
# A: Few-shot and zero-shot learning for data augmentation.
#
# Q: Which benchmarks or evaluation methods are referenced?
# A: GLUE, SuperGLUE, and M3 and M4 competitions.
#
# Q: What novel methods or improvements are introduced?
# A: Chain of Self-Correction (CoSC) for improving mathematical reasoning.
#
# Q: Which datasets or resources are utilized in the research?
# A: Yahoo, Numenta, NASA anomaly detection datasets.
#
# Q: How does the proposed approach improve upon existing methods?
# A: CoSC models reasoning as a multi-round procedure, improving verification.
#
# Q: What applications or domains are addressed by the model?
# A: Sentiment analysis, hate speech detection, low-resource language generation.
#
# Q: What limitations or areas for future exploration are identified?
# A: Effects of different merging techniques are not fully examined.
#
# Q: What is the overall objective or goal of the research?
# A: To understand the progress in NLP and time series modeling using benchmarks.
#
# Q: Which specific models or frameworks are analyzed or compared?
# A: Task Arithmetic, TIES, and Model Breadcrumbs in model merging.
#
# Q: What methodologies or experimental setups are described in detail?
# A: AFlow's use of named nodes and MCTS algorithm for workflow discovery.
#
# Q: What significant findings or conclusions are drawn from the study?
# A: Effective continuous pre-training enhances knowledge acquisition in LLMs.
#
# Q: What recommendations or implications does the study suggest?
# A: Exploration of human-inspired sample selection strategies to improve performance.

# %% [markdown]
# ## Deduplicated Questions

# %%
def highlight_rows(row):
    if row['selected'] == 'x':
        return ['background-color: lightgreen'] * len(row)
    else:
        return ['background-color: lightgray'] * len(row)


def show_deduplicated_qas(qa_file):
    df = pd.read_excel(qa_file, sheet_name='clustered')
    df = df.rename({'centroid': 'question'}, axis=1)
    df = df[['question', 'group_name', 'cluster_size', 'selected']]
    df.loc[df['group_name'] == 'NOISE', 'question'] = '--'

    styled_df = (
        df.style
        .apply(highlight_rows, axis=1)  # Apply row-wise styling
        .hide(['selected'], axis=1)     # Hide the 'selected' column
    )
    display(styled_df)

# %%
show_deduplicated_qas('../data/annotations/questions/qmsum-generic-clusters-manual.xlsx')
# Out:
# <style type="text/css">
# #T_98e2d_row0_col0, #T_98e2d_row0_col1, #T_98e2d_row0_col2, #T_98e2d_row2_col0, #T_98e2d_row2_col1, #T_98e2d_row2_col2, #T_98e2d_row4_col0, #T_98e2d_row4_col1, #T_98e2d_row4_col2, #T_98e2d_row5_col0, #T_98e2d_row5_col1, #T_98e2d_row5_col2, #T_98e2d_row8_col0, #T_98e2d_row8_col1, #T_98e2d_row8_col2, #T_98e2d_row10_col0, #T_98e2d_row10_col1, #T_98e2d_row10_col2, #T_98e2d_row16_col0, #T_98e2d_row16_col1, #T_98e2d_row16_col2, #T_98e2d_row17_col0, #T_98e2d_row17_col1, #T_98e2d_row17_col2, #T_98e2d_row18_col0, #T_98e2d_row18_col1, #T_98e2d_row18_col2 {
#   background-color: lightgray;
# }
# #T_98e2d_row1_col0, #T_98e2d_row1_col1, #T_98e2d_row1_col2, #T_98e2d_row3_col0, #T_98e2d_row3_col1, #T_98e2d_row3_col2, #T_98e2d_row6_col0, #T_98e2d_row6_col1, #T_98e2d_row6_col2, #T_98e2d_row7_col0, #T_98e2d_row7_col1, #T_98e2d_row7_col2, #T_98e2d_row9_col0, #T_98e2d_row9_col1, #T_98e2d_row9_col2, #T_98e2d_row11_col0, #T_98e2d_row11_col1, #T_98e2d_row11_col2, #T_98e2d_row12_col0, #T_98e2d_row12_col1, #T_98e2d_row12_col2, #T_98e2d_row13_col0, #T_98e2d_row13_col1, #T_98e2d_row13_col2, #T_98e2d_row14_col0, #T_98e2d_row14_col1, #T_98e2d_row14_col2, #T_98e2d_row15_col0, #T_98e2d_row15_col1, #T_98e2d_row15_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_98e2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98e2d_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_98e2d_level0_col1" class="col_heading level0 col1" >group_name</th>
#       <th id="T_98e2d_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98e2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98e2d_row0_col0" class="data row0 col0" >--</td>
#       <td id="T_98e2d_row0_col1" class="data row0 col1" >NOISE</td>
#       <td id="T_98e2d_row0_col2" class="data row0 col2" >293</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98e2d_row1_col0" class="data row1 col0" >Who are the participants and their roles discussed in the meeting?</td>
#       <td id="T_98e2d_row1_col1" class="data row1 col1" >Participants -- roles</td>
#       <td id="T_98e2d_row1_col2" class="data row1 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98e2d_row2_col0" class="data row2 col0" >Who were the key participants or roles involved in the meeting?</td>
#       <td id="T_98e2d_row2_col1" class="data row2 col1" >Participants -- roles</td>
#       <td id="T_98e2d_row2_col2" class="data row2 col2" >35</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98e2d_row3_col0" class="data row3 col0" >What main topic was discussed in the meeting?</td>
#       <td id="T_98e2d_row3_col1" class="data row3 col1" >Topic -- main</td>
#       <td id="T_98e2d_row3_col2" class="data row3 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98e2d_row4_col0" class="data row4 col0" >What are the main topics discussed in the meeting?</td>
#       <td id="T_98e2d_row4_col1" class="data row4 col1" >Topic -- main</td>
#       <td id="T_98e2d_row4_col2" class="data row4 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98e2d_row5_col0" class="data row5 col0" >What is the primary topic of the meeting?</td>
#       <td id="T_98e2d_row5_col1" class="data row5 col1" >Topic -- main</td>
#       <td id="T_98e2d_row5_col2" class="data row5 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98e2d_row6_col0" class="data row6 col0" >What were the main objectives or goals discussed in the meeting?</td>
#       <td id="T_98e2d_row6_col1" class="data row6 col1" >Topic -- goals</td>
#       <td id="T_98e2d_row6_col2" class="data row6 col2" >27</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98e2d_row7_col0" class="data row7 col0" >Which aspects of the main topic were covered in the discussion?</td>
#       <td id="T_98e2d_row7_col1" class="data row7 col1" >Topic -- aspects</td>
#       <td id="T_98e2d_row7_col2" class="data row7 col2" >64</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98e2d_row8_col0" class="data row8 col0" >What aspect of the project was primarily discussed?</td>
#       <td id="T_98e2d_row8_col1" class="data row8 col1" >Topic -- aspects</td>
#       <td id="T_98e2d_row8_col2" class="data row8 col2" >33</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98e2d_row9_col0" class="data row9 col0" >What are the identified challenges or concerns discussed?</td>
#       <td id="T_98e2d_row9_col1" class="data row9 col1" >Discussion -- challenges</td>
#       <td id="T_98e2d_row9_col2" class="data row9 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98e2d_row10_col0" class="data row10 col0" >What specific issues or challenges were identified during the meeting?</td>
#       <td id="T_98e2d_row10_col1" class="data row10 col1" >Discussion -- challenges</td>
#       <td id="T_98e2d_row10_col2" class="data row10 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98e2d_row11_col0" class="data row11 col0" >What detailed strategies or solutions were proposed for the challenges discussed?</td>
#       <td id="T_98e2d_row11_col1" class="data row11 col1" >Discussion -- solutions</td>
#       <td id="T_98e2d_row11_col2" class="data row11 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98e2d_row12_col0" class="data row12 col0" >What were the anticipated impacts or implications discussed?</td>
#       <td id="T_98e2d_row12_col1" class="data row12 col1" >Discussion -- solution impacts</td>
#       <td id="T_98e2d_row12_col2" class="data row12 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98e2d_row13_col0" class="data row13 col0" >What were the major outcomes or decisions made during the meeting?</td>
#       <td id="T_98e2d_row13_col1" class="data row13 col1" >Outcomes -- decisions</td>
#       <td id="T_98e2d_row13_col2" class="data row13 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98e2d_row14_col0" class="data row14 col0" >What collaborative efforts or partnerships were discussed?</td>
#       <td id="T_98e2d_row14_col1" class="data row14 col1" >Outcomes -- collaborations</td>
#       <td id="T_98e2d_row14_col2" class="data row14 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98e2d_row15_col0" class="data row15 col0" >What potential future steps or actions were planned in the meeting?</td>
#       <td id="T_98e2d_row15_col1" class="data row15 col1" >Outcomes -- actions</td>
#       <td id="T_98e2d_row15_col2" class="data row15 col2" >41</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98e2d_row16_col0" class="data row16 col0" >Which design features were important in the discussion?</td>
#       <td id="T_98e2d_row16_col1" class="data row16 col1" >xxx -- specific?</td>
#       <td id="T_98e2d_row16_col2" class="data row16 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_98e2d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98e2d_row17_col0" class="data row17 col0" >What methodologies or strategies we

# %%
show_deduplicated_qas('../data/annotations/questions/pubmed-sample-clusters-manual.xlsx')
# Out:
# <style type="text/css">
# #T_c8893_row0_col0, #T_c8893_row0_col1, #T_c8893_row0_col2, #T_c8893_row2_col0, #T_c8893_row2_col1, #T_c8893_row2_col2, #T_c8893_row7_col0, #T_c8893_row7_col1, #T_c8893_row7_col2, #T_c8893_row8_col0, #T_c8893_row8_col1, #T_c8893_row8_col2, #T_c8893_row9_col0, #T_c8893_row9_col1, #T_c8893_row9_col2, #T_c8893_row13_col0, #T_c8893_row13_col1, #T_c8893_row13_col2, #T_c8893_row15_col0, #T_c8893_row15_col1, #T_c8893_row15_col2, #T_c8893_row18_col0, #T_c8893_row18_col1, #T_c8893_row18_col2, #T_c8893_row20_col0, #T_c8893_row20_col1, #T_c8893_row20_col2, #T_c8893_row24_col0, #T_c8893_row24_col1, #T_c8893_row24_col2, #T_c8893_row25_col0, #T_c8893_row25_col1, #T_c8893_row25_col2, #T_c8893_row26_col0, #T_c8893_row26_col1, #T_c8893_row26_col2, #T_c8893_row27_col0, #T_c8893_row27_col1, #T_c8893_row27_col2, #T_c8893_row28_col0, #T_c8893_row28_col1, #T_c8893_row28_col2, #T_c8893_row33_col0, #T_c8893_row33_col1, #T_c8893_row33_col2, #T_c8893_row34_col0, #T_c8893_row34_col1, #T_c8893_row34_col2, #T_c8893_row35_col0, #T_c8893_row35_col1, #T_c8893_row35_col2 {
#   background-color: lightgray;
# }
# #T_c8893_row1_col0, #T_c8893_row1_col1, #T_c8893_row1_col2, #T_c8893_row3_col0, #T_c8893_row3_col1, #T_c8893_row3_col2, #T_c8893_row4_col0, #T_c8893_row4_col1, #T_c8893_row4_col2, #T_c8893_row5_col0, #T_c8893_row5_col1, #T_c8893_row5_col2, #T_c8893_row6_col0, #T_c8893_row6_col1, #T_c8893_row6_col2, #T_c8893_row10_col0, #T_c8893_row10_col1, #T_c8893_row10_col2, #T_c8893_row11_col0, #T_c8893_row11_col1, #T_c8893_row11_col2, #T_c8893_row12_col0, #T_c8893_row12_col1, #T_c8893_row12_col2, #T_c8893_row14_col0, #T_c8893_row14_col1, #T_c8893_row14_col2, #T_c8893_row16_col0, #T_c8893_row16_col1, #T_c8893_row16_col2, #T_c8893_row17_col0, #T_c8893_row17_col1, #T_c8893_row17_col2, #T_c8893_row19_col0, #T_c8893_row19_col1, #T_c8893_row19_col2, #T_c8893_row21_col0, #T_c8893_row21_col1, #T_c8893_row21_col2, #T_c8893_row22_col0, #T_c8893_row22_col1, #T_c8893_row22_col2, #T_c8893_row23_col0, #T_c8893_row23_col1, #T_c8893_row23_col2, #T_c8893_row29_col0, #T_c8893_row29_col1, #T_c8893_row29_col2, #T_c8893_row30_col0, #T_c8893_row30_col1, #T_c8893_row30_col2, #T_c8893_row31_col0, #T_c8893_row31_col1, #T_c8893_row31_col2, #T_c8893_row32_col0, #T_c8893_row32_col1, #T_c8893_row32_col2, #T_c8893_row36_col0, #T_c8893_row36_col1, #T_c8893_row36_col2, #T_c8893_row37_col0, #T_c8893_row37_col1, #T_c8893_row37_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c8893">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8893_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_c8893_level0_col1" class="col_heading level0 col1" >group_name</th>
#       <th id="T_c8893_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8893_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8893_row0_col0" class="data row0 col0" >--</td>
#       <td id="T_c8893_row0_col1" class="data row0 col1" >NOISE</td>
#       <td id="T_c8893_row0_col2" class="data row0 col2" >609</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8893_row1_col0" class="data row1 col0" >What is the main focus of the study?</td>
#       <td id="T_c8893_row1_col1" class="data row1 col1" >Topic</td>
#       <td id="T_c8893_row1_col2" class="data row1 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8893_row2_col0" class="data row2 col0" >Which population is the study focused on?</td>
#       <td id="T_c8893_row2_col1" class="data row2 col1" >Population</td>
#       <td id="T_c8893_row2_col2" class="data row2 col2" >53</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8893_row3_col0" class="data row3 col0" >Which patient population is the study concerned with?</td>
#       <td id="T_c8893_row3_col1" class="data row3 col1" >Population</td>
#       <td id="T_c8893_row3_col2" class="data row3 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8893_row4_col0" class="data row4 col0" >What condition is being addressed in the study?</td>
#       <td id="T_c8893_row4_col1" class="data row4 col1" >Population -- Condition</td>
#       <td id="T_c8893_row4_col2" class="data row4 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8893_row5_col0" class="data row5 col0" >What is the participant demographic or characteristics in the study?</td>
#       <td id="T_c8893_row5_col1" class="data row5 col1" >Population -- demographics</td>
#       <td id="T_c8893_row5_col2" class="data row5 col2" >33</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8893_row6_col0" class="data row6 col0" >What was the main intervention used in the study?</td>
#       <td id="T_c8893_row6_col1" class="data row6 col1" >Intervention</td>
#       <td id="T_c8893_row6_col2" class="data row6 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8893_row7_col0" class="data row7 col0" >What is the primary intervention being studied?</td>
#       <td id="T_c8893_row7_col1" class="data row7 col1" >Intervention</td>
#       <td id="T_c8893_row7_col2" class="data row7 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8893_row8_col0" class="data row8 col0" >What is the main treatment or intervention being evaluated?</td>
#       <td id="T_c8893_row8_col1" class="data row8 col1" >Intervention</td>
#       <td id="T_c8893_row8_col2" class="data row8 col2" >36</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8893_row9_col0" class="data row9 col0" >What is the main intervention or treatment studied?</td>
#       <td id="T_c8893_row9_col1" class="data row9 col1" >Intervention</td>
#       <td id="T_c8893_row9_col2" class="data row9 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c8893_row10_col0" class="data row10 col0" >What are the significant benefits of the intervention?</td>
#       <td id="T_c8893_row10_col1" class="data row10 col1" >Intervention -- benefits</td>
#       <td id="T_c8893_row10_col2" class="data row10 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c8893_row11_col0" class="data row11 col0" >What are the specific biological markers influenced by the intervention?</td>
#       <td id="T_c8893_row11_col1" class="data row11 col1" >Intervention -- biomarkers</td>
#       <td id="T_c8893_row11_col2" class="data row11 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c8893_row12_col0" class="data row12 col0" >What specific treatments were compared in the study?</td>
#       <td id="T_c8893_row12_col1" class="data row12 col1" >Comparators</td>
#       <td id="T_c8893_row12_col2" class="data row12 col2" >67</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c8893_row13_col0" class="data row13 col0" >Which groups or comparisons are detailed in the study?</td>
#       <td id="T_c8893_row13_col1" class="data row13 col1" >Comparators</td>
#       <td id="T_c8893_row13_col2" class="data row13 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_c8893_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c8893_row14_col0" class="data row14 col0" >What specific metrics or outcomes were measured?</td>
#       <td id="T_c8893_row14_col1" class="data row14 col1

# %%
show_deduplicated_qas('../data/annotations/questions/cs-cl-clusters-manual.xlsx')
# Out:
# <style type="text/css">
# #T_e3e8b_row0_col0, #T_e3e8b_row0_col1, #T_e3e8b_row0_col2, #T_e3e8b_row2_col0, #T_e3e8b_row2_col1, #T_e3e8b_row2_col2, #T_e3e8b_row3_col0, #T_e3e8b_row3_col1, #T_e3e8b_row3_col2, #T_e3e8b_row4_col0, #T_e3e8b_row4_col1, #T_e3e8b_row4_col2, #T_e3e8b_row5_col0, #T_e3e8b_row5_col1, #T_e3e8b_row5_col2, #T_e3e8b_row7_col0, #T_e3e8b_row7_col1, #T_e3e8b_row7_col2, #T_e3e8b_row8_col0, #T_e3e8b_row8_col1, #T_e3e8b_row8_col2, #T_e3e8b_row11_col0, #T_e3e8b_row11_col1, #T_e3e8b_row11_col2, #T_e3e8b_row14_col0, #T_e3e8b_row14_col1, #T_e3e8b_row14_col2, #T_e3e8b_row16_col0, #T_e3e8b_row16_col1, #T_e3e8b_row16_col2, #T_e3e8b_row17_col0, #T_e3e8b_row17_col1, #T_e3e8b_row17_col2, #T_e3e8b_row18_col0, #T_e3e8b_row18_col1, #T_e3e8b_row18_col2, #T_e3e8b_row19_col0, #T_e3e8b_row19_col1, #T_e3e8b_row19_col2, #T_e3e8b_row20_col0, #T_e3e8b_row20_col1, #T_e3e8b_row20_col2, #T_e3e8b_row23_col0, #T_e3e8b_row23_col1, #T_e3e8b_row23_col2, #T_e3e8b_row24_col0, #T_e3e8b_row24_col1, #T_e3e8b_row24_col2, #T_e3e8b_row25_col0, #T_e3e8b_row25_col1, #T_e3e8b_row25_col2, #T_e3e8b_row26_col0, #T_e3e8b_row26_col1, #T_e3e8b_row26_col2, #T_e3e8b_row27_col0, #T_e3e8b_row27_col1, #T_e3e8b_row27_col2, #T_e3e8b_row31_col0, #T_e3e8b_row31_col1, #T_e3e8b_row31_col2, #T_e3e8b_row34_col0, #T_e3e8b_row34_col1, #T_e3e8b_row34_col2, #T_e3e8b_row35_col0, #T_e3e8b_row35_col1, #T_e3e8b_row35_col2 {
#   background-color: lightgray;
# }
# #T_e3e8b_row1_col0, #T_e3e8b_row1_col1, #T_e3e8b_row1_col2, #T_e3e8b_row6_col0, #T_e3e8b_row6_col1, #T_e3e8b_row6_col2, #T_e3e8b_row9_col0, #T_e3e8b_row9_col1, #T_e3e8b_row9_col2, #T_e3e8b_row10_col0, #T_e3e8b_row10_col1, #T_e3e8b_row10_col2, #T_e3e8b_row12_col0, #T_e3e8b_row12_col1, #T_e3e8b_row12_col2, #T_e3e8b_row13_col0, #T_e3e8b_row13_col1, #T_e3e8b_row13_col2, #T_e3e8b_row15_col0, #T_e3e8b_row15_col1, #T_e3e8b_row15_col2, #T_e3e8b_row21_col0, #T_e3e8b_row21_col1, #T_e3e8b_row21_col2, #T_e3e8b_row22_col0, #T_e3e8b_row22_col1, #T_e3e8b_row22_col2, #T_e3e8b_row28_col0, #T_e3e8b_row28_col1, #T_e3e8b_row28_col2, #T_e3e8b_row29_col0, #T_e3e8b_row29_col1, #T_e3e8b_row29_col2, #T_e3e8b_row30_col0, #T_e3e8b_row30_col1, #T_e3e8b_row30_col2, #T_e3e8b_row32_col0, #T_e3e8b_row32_col1, #T_e3e8b_row32_col2, #T_e3e8b_row33_col0, #T_e3e8b_row33_col1, #T_e3e8b_row33_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3e8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3e8b_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_e3e8b_level0_col1" class="col_heading level0 col1" >group_name</th>
#       <th id="T_e3e8b_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3e8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3e8b_row0_col0" class="data row0 col0" >--</td>
#       <td id="T_e3e8b_row0_col1" class="data row0 col1" >NOISE</td>
#       <td id="T_e3e8b_row0_col2" class="data row0 col2" >541</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3e8b_row1_col0" class="data row1 col0" >What main topic is the document addressing?</td>
#       <td id="T_e3e8b_row1_col1" class="data row1 col1" >Main topic</td>
#       <td id="T_e3e8b_row1_col2" class="data row1 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3e8b_row2_col0" class="data row2 col0" >What is the main focus of the research?</td>
#       <td id="T_e3e8b_row2_col1" class="data row2 col1" >Main topic</td>
#       <td id="T_e3e8b_row2_col2" class="data row2 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3e8b_row3_col0" class="data row3 col0" >What is the main focus of the study?</td>
#       <td id="T_e3e8b_row3_col1" class="data row3 col1" >Main topic</td>
#       <td id="T_e3e8b_row3_col2" class="data row3 col2" >31</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3e8b_row4_col0" class="data row4 col0" >What is the main focus of the document?</td>
#       <td id="T_e3e8b_row4_col1" class="data row4 col1" >Main topic</td>
#       <td id="T_e3e8b_row4_col2" class="data row4 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3e8b_row5_col0" class="data row5 col0" >What domain or area does the research emphasize?</td>
#       <td id="T_e3e8b_row5_col1" class="data row5 col1" >Main topic</td>
#       <td id="T_e3e8b_row5_col2" class="data row5 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3e8b_row6_col0" class="data row6 col0" >What are the main approaches or techniques discussed in the document?</td>
#       <td id="T_e3e8b_row6_col1" class="data row6 col1" >Main techniques</td>
#       <td id="T_e3e8b_row6_col2" class="data row6 col2" >96</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3e8b_row7_col0" class="data row7 col0" >What is the main technique or method discussed?</td>
#       <td id="T_e3e8b_row7_col1" class="data row7 col1" >Main techniques</td>
#       <td id="T_e3e8b_row7_col2" class="data row7 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3e8b_row8_col0" class="data row8 col0" >Which specific technologies or methodologies are mentioned?</td>
#       <td id="T_e3e8b_row8_col1" class="data row8 col1" >Main techniques</td>
#       <td id="T_e3e8b_row8_col2" class="data row8 col2" >38</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3e8b_row9_col0" class="data row9 col0" >What recent advancements or innovations are highlighted in the document?</td>
#       <td id="T_e3e8b_row9_col1" class="data row9 col1" >Recent advances</td>
#       <td id="T_e3e8b_row9_col2" class="data row9 col2" >92</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e3e8b_row10_col0" class="data row10 col0" >How does the study relate to previous research in the field?</td>
#       <td id="T_e3e8b_row10_col1" class="data row10 col1" >Relate to prior -- comparison</td>
#       <td id="T_e3e8b_row10_col2" class="data row10 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e3e8b_row11_col0" class="data row11 col0" >Which specific area of research does the document contribute to?</td>
#       <td id="T_e3e8b_row11_col1" class="data row11 col1" >Relate to prior -- comparison</td>
#       <td id="T_e3e8b_row11_col2" class="data row11 col2" >27</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e3e8b_row12_col0" class="data row12 col0" >Which previous works or studies are referenced?</td>
#       <td id="T_e3e8b_row12_col1" class="data row12 col1" >Relate to prior -- references</td>
#       <td id="T_e3e8b_row12_col2" class="data row12 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e3e8b_row13_col0" class="data row13 col0" >What is a prominent method mentioned for enhancing model effectiveness?</td>
#       <td id="T_e3e8b_row13_col1" class="data row13 col1" >Current SOTA</td>
#       <td id="T_e3e8b_row13_col2" class="data row13 col2" >38</td>
#     </tr>
#     <tr>
#       <th id="T_e3e8b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e3e8b_row14_col0" class="data row14 col0" >What limitations or challenges are identified in the existing methods?</td>
#       <td id="T_e3e8b_row14_col1" class="data row14 col1" >Existing limitations</td>
#       <td id="T_e3e8b_row14_col2" class="data row

# %%
show_deduplicated_qas('../data/annotations/questions/astro-ph-clusters-manual.xlsx')
# Out:
# <style type="text/css">
# #T_400e7_row0_col0, #T_400e7_row0_col1, #T_400e7_row0_col2, #T_400e7_row2_col0, #T_400e7_row2_col1, #T_400e7_row2_col2, #T_400e7_row6_col0, #T_400e7_row6_col1, #T_400e7_row6_col2, #T_400e7_row8_col0, #T_400e7_row8_col1, #T_400e7_row8_col2, #T_400e7_row11_col0, #T_400e7_row11_col1, #T_400e7_row11_col2, #T_400e7_row17_col0, #T_400e7_row17_col1, #T_400e7_row17_col2, #T_400e7_row19_col0, #T_400e7_row19_col1, #T_400e7_row19_col2 {
#   background-color: lightgray;
# }
# #T_400e7_row1_col0, #T_400e7_row1_col1, #T_400e7_row1_col2, #T_400e7_row3_col0, #T_400e7_row3_col1, #T_400e7_row3_col2, #T_400e7_row4_col0, #T_400e7_row4_col1, #T_400e7_row4_col2, #T_400e7_row5_col0, #T_400e7_row5_col1, #T_400e7_row5_col2, #T_400e7_row7_col0, #T_400e7_row7_col1, #T_400e7_row7_col2, #T_400e7_row9_col0, #T_400e7_row9_col1, #T_400e7_row9_col2, #T_400e7_row10_col0, #T_400e7_row10_col1, #T_400e7_row10_col2, #T_400e7_row12_col0, #T_400e7_row12_col1, #T_400e7_row12_col2, #T_400e7_row13_col0, #T_400e7_row13_col1, #T_400e7_row13_col2, #T_400e7_row14_col0, #T_400e7_row14_col1, #T_400e7_row14_col2, #T_400e7_row15_col0, #T_400e7_row15_col1, #T_400e7_row15_col2, #T_400e7_row16_col0, #T_400e7_row16_col1, #T_400e7_row16_col2, #T_400e7_row18_col0, #T_400e7_row18_col1, #T_400e7_row18_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_400e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_400e7_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_400e7_level0_col1" class="col_heading level0 col1" >group_name</th>
#       <th id="T_400e7_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_400e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_400e7_row0_col0" class="data row0 col0" >--</td>
#       <td id="T_400e7_row0_col1" class="data row0 col1" >NOISE</td>
#       <td id="T_400e7_row0_col2" class="data row0 col2" >273</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_400e7_row1_col0" class="data row1 col0" >What is the main focus of the study?</td>
#       <td id="T_400e7_row1_col1" class="data row1 col1" >Topic - main</td>
#       <td id="T_400e7_row1_col2" class="data row1 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_400e7_row2_col0" class="data row2 col0" >What is the primary focus or issue discussed?</td>
#       <td id="T_400e7_row2_col1" class="data row2 col1" >Topic - main</td>
#       <td id="T_400e7_row2_col2" class="data row2 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_400e7_row3_col0" class="data row3 col0" >What specific phenomena or processes are being investigated in the study?</td>
#       <td id="T_400e7_row3_col1" class="data row3 col1" >Topic - phenomena processes</td>
#       <td id="T_400e7_row3_col2" class="data row3 col2" >109</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_400e7_row4_col0" class="data row4 col0" >What broader context or field does the study contribute to or address?</td>
#       <td id="T_400e7_row4_col1" class="data row4 col1" >Topic -- context</td>
#       <td id="T_400e7_row4_col2" class="data row4 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_400e7_row5_col0" class="data row5 col0" >What specific challenges or limitations does the study address or identify?</td>
#       <td id="T_400e7_row5_col1" class="data row5 col1" >Challenges and limitations</td>
#       <td id="T_400e7_row5_col2" class="data row5 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_400e7_row6_col0" class="data row6 col0" >What are the main challenges or limitations identified?</td>
#       <td id="T_400e7_row6_col1" class="data row6 col1" >Challenges and limitations</td>
#       <td id="T_400e7_row6_col2" class="data row6 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_400e7_row7_col0" class="data row7 col0" >What methodology or techniques are employed in the study?</td>
#       <td id="T_400e7_row7_col1" class="data row7 col1" >Method</td>
#       <td id="T_400e7_row7_col2" class="data row7 col2" >99</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_400e7_row8_col0" class="data row8 col0" >What methodologies or techniques are discussed?</td>
#       <td id="T_400e7_row8_col1" class="data row8 col1" >Method</td>
#       <td id="T_400e7_row8_col2" class="data row8 col2" >56</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_400e7_row9_col0" class="data row9 col0" >What comparisons are made within the study?</td>
#       <td id="T_400e7_row9_col1" class="data row9 col1" >Method -- comparisons</td>
#       <td id="T_400e7_row9_col2" class="data row9 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_400e7_row10_col0" class="data row10 col0" >What are the main findings of the study?</td>
#       <td id="T_400e7_row10_col1" class="data row10 col1" >Results -- overall</td>
#       <td id="T_400e7_row10_col2" class="data row10 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_400e7_row11_col0" class="data row11 col0" >What key finding was highlighted?</td>
#       <td id="T_400e7_row11_col1" class="data row11 col1" >Results -- overall</td>
#       <td id="T_400e7_row11_col2" class="data row11 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_400e7_row12_col0" class="data row12 col0" >What detailed evidence or data is used to support the study's claims?</td>
#       <td id="T_400e7_row12_col1" class="data row12 col1" >Results -- evidence</td>
#       <td id="T_400e7_row12_col2" class="data row12 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_400e7_row13_col0" class="data row13 col0" >What specific variables or conditions are crucial in the study's findings?</td>
#       <td id="T_400e7_row13_col1" class="data row13 col1" >Results -- parameters conditions</td>
#       <td id="T_400e7_row13_col2" class="data row13 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_400e7_row14_col0" class="data row14 col0" >How do the findings relate to existing models or theories?</td>
#       <td id="T_400e7_row14_col1" class="data row14 col1" >Discussion -- existing theories</td>
#       <td id="T_400e7_row14_col2" class="data row14 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_400e7_row15_col0" class="data row15 col0" >How do the findings affect the understanding of astronomical systems?</td>
#       <td id="T_400e7_row15_col1" class="data row15 col1" >Discussion -- understanding</td>
#       <td id="T_400e7_row15_col2" class="data row15 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_400e7_row16_col0" class="data row16 col0" >What are the broader implications or potential applications of the findings?</td>
#       <td id="T_400e7_row16_col1" class="data row16 col1" >Discussion -- implications</td>
#       <td id="T_400e7_row16_col2" class="data row16 col2" >38</td>
#     </tr>
#     <tr>
#       <th id="T_400e7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_400e7_row17_col0" class="data row17 co
