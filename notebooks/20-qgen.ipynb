# %% [markdown]
# # Question Generation and Clustering

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from info_salience import qgen

# %%
import json
from typing import List, Dict
from pathlib import Path
from collections import defaultdict

import pandas as pd
import outlines
from sentence_transformers import SentenceTransformer
from json_repair import repair_json
from dotenv import find_dotenv, load_dotenv
import hdbscan
import umap
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from InstructorEmbedding import INSTRUCTOR

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
from info_salience.llm import LitellmGenerator

llm = LitellmGenerator(
    "gpt-4o-2024-08-06",
    caching=True,
    report_costs=True,
    disk_cache_dir=f".litellm_cache",
)

# %% [markdown]
# This is the interface
#
# ```python
# def generate_questions(df_summaries) -> List[str]:
#     pass
#
#
# def cluster_questions(questions):
#     # embed
#     # reduce dim
#     # cluster
#     return embeddings, assignments
#
#
# def calculate_centroids(questions, embeddings, assignments) -> Dict[int,str]:
#     pass
#
#
# def aggregate_data(questions, assignments, centroids):
#     return df_agg
#
#
# def generate_report(df_agg):
#     pass
# ```

# %%
def calculate_centroids(questions, embeddings, assignments) -> Dict[int, str]:
    grouped = defaultdict(list)
    for cluster_id, question_id in zip(assignments, range(len(questions))):
        grouped[cluster_id].append(question_id)

    centroids = {}
    for cluster_id, question_ids in grouped.items():
        mean_embedding = np.mean(embeddings[question_ids], axis=0)
        scores = cosine_similarity([mean_embedding], embeddings[question_ids])
        best_match_id = question_ids[scores.argmax()]
        centroid = questions[best_match_id]
        centroids[cluster_id] = centroid
    return centroids


def aggregate_data(questions, assignments, centroids):
    df_questions = pd.DataFrame({"question": questions, "cluster_id": assignments})
    df_centroids = pd.DataFrame(
        {"cluster_id": centroids.keys(), "centroid": centroids.values()}
    )

    df_agg = pd.merge(
        df_questions.groupby("cluster_id")["question"].apply(list),
        df_centroids,
        on="cluster_id",
    )
    df_agg["cluster_size"] = df_agg["question"].apply(len)
    df_agg = df_agg.set_index("cluster_id")
    return df_agg


def generate_report(df_agg):
    n_questions = df_agg["cluster_size"].sum()
    n_clusters = len(df_agg)

    print("=" * 80)
    print(f"Total generated questions: {n_questions}")
    print(f"Number of clusters: {n_clusters}")
    if -1 in df_agg.index:
        n_clusters = n_clusters - 1
        n_noise = df_agg.loc[-1]["cluster_size"]
        print(f"Classified as noise: {n_noise} ({n_noise/n_questions*100:.2f}%)")
    print("=" * 80)

    print(
        df_agg.loc[0:]
        .sort_values("cluster_size", ascending=False)[["centroid", "cluster_size"]]
        .to_markdown()
    )

    print()

    for index, row in df_agg.sort_values('cluster_size', ascending=False).iterrows():
        print('='*80)
        if index == -1:
            print('NOISE CLUSTER')
        print(row['centroid'])
        print(f'N = {len(row["question"])}')
        print('='*80)
        for question in row['question'][:10]:
            print(question)
        print(f'... {len(row["question"][10:])} others ...')
        print()

# %% [markdown]
# ## Sample outputs contrastive prompt

# %%
df_summaries = pd.read_json('../output/cs-cl/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json')
df_summaries = df_summaries.sample(frac=1.0, random_state=42)  # shuffle
questions = qgen.generate_questions(llm, df_summaries.head(10), topic='cs-cl', debug=True)
# Out:
# Batch cost: $0.0288
# ==============================
# questions_10_words
# Q: What is the main focus of the research discussed?
# Q: Which methods are highlighted in the research?
# Q: What aspect of NLP does the document address?
#
# questions_20_words
# Q: What challenge or problem does the research aim to address?
# Q: Which techniques or models are mentioned as a focus in the research?
# Q: How does the research propose addressing the identified challenges?
#
# questions_50_words
# Q: What specific problem with existing models is being targeted in the research?
# Q: Which strategies or innovations does the research propose for overcoming the challenges?
# Q: In what way does the research aim to improve model performance?
#
# questions_100_words
# Q: What are the limitations of current approaches discussed in the research?
# Q: How does the proposed method differ from existing solutions?
# Q: Which specific techniques are compared or contrasted in the document?
# Q: What are the intended outcomes of using the proposed method?
#
# questions_200_words
# Q: What broader implications does the research suggest for the NLP field?
# Q: How does the research address the limitations of existing benchmarks or methodologies?
# Q: What are some areas of future research or open questions identified?
# Q: What challenges associated with low-resource languages are acknowledged in the research?
# Q: What methods are integrated within the proposed framework to enhance document understanding?
#
# ==============================
# questions_10_words
# Q: What is the main focus of the study?
# Q: What methodology is highlighted in the research?
# Q: What challenge is addressed by language agents?
#
# questions_20_words
# Q: How does the study compare AI-generated content?
# Q: What enhancement method is discussed for multimodal embedding tasks?
# Q: What modules do language agents involve?
#
# questions_50_words
# Q: How does the study evaluate human likeness in generated content?
# Q: What goal is achieved by integrating graph data with language models?
# Q: What challenges do language agents encounter in real-world applications?
#
# questions_100_words
# Q: Which strategies and tools are employed to evaluate counterspeech?
# Q: What unique alignment mechanism is introduced for graph and text embeddings?
# Q: What real-world capabilities do language agents extend to?
#
# questions_200_words
# Q: What types of models are utilized for counterspeech generation, and how are they evaluated?
# Q: How does the proposed approach improve the alignment of graph and text embeddings?
# Q: What interpretability methods are suggested to improve language agent transparency?
# Q: What methods integrate speech processing models with LLMs, and what tasks benefit?
# Q: What challenges persist for LLMs in cross-domain reasoning tasks?

# %% [markdown]
# # Generate and cluster questions with contrastive prompt

# %%
from pathlib import Path

def generate_questions(summaries_json, topic, debug=False, force=False):
    summaries_json = Path(summaries_json)
    out_json = summaries_json.parent.parent / 'discord-qa-contrastive' / 'questions.json'
    if not force and out_json.exists():
        print(f'Load existing questions: {out_json}')
        with open(out_json) as fin:
            questions = json.load(fin)['questions']

    else:
        df_summaries = pd.read_json(summaries_json)
        df_summaries = df_summaries.sample(frac=1.0, random_state=42)  # shuffle
        questions = qgen.generate_questions(llm, df_summaries, topic=topic, debug=debug)

        out_json.parent.mkdir(exist_ok=True, parents=True)
        with open(out_json, 'w') as fout:
            print(f'Save {len(questions)} questions to {out_json}')
            json.dump({'questions': questions}, fout)

    return questions

# %%
def cluster_questions(questions, min_cluster_size=5, min_samples=None):
    minilm = SentenceTransformer("all-mpnet-base-v2")
    embeddings = minilm.encode(questions, normalize_embeddings=True)

    umap_model = umap.UMAP(
        n_neighbors=15,
        n_components=5,
        min_dist=0.0,
        metric='cosine',
        n_jobs=1,
        random_state=42
    )
    embeddings_ = umap_model.fit_transform(embeddings)

    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=min_samples,
        cluster_selection_method='leaf',
    )
    clusterer.fit(embeddings_)
    return embeddings, clusterer.labels_

# %% [markdown]
# ## astro-ph

# %%
questions = []
questions += generate_questions('../output/astro-ph/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json', 'astro-ph')
questions += generate_questions('../output/astro-ph/Mistral-7B-Instruct-v0.3/summaries/temperature0.3-0.json', 'astro-ph')
questions += generate_questions('../output/astro-ph/gpt-4o-2024-08-06/summaries/temperature0.3-0.json', 'astro-ph')
# Out:
# Batch cost: $0.3033
# Save 362 questions to ../output/astro-ph/Meta-Llama-3.1-8B-Instruct/discord-qa-contrastive/questions.json
# Batch cost: $0.3055
# Save 369 questions to ../output/astro-ph/Mistral-7B-Instruct-v0.3/discord-qa-contrastive/questions.json
# Batch cost: $0.3314
# Save 383 questions to ../output/astro-ph/gpt-4o-2024-08-06/discord-qa-contrastive/questions.json

# %%
embeddings, assignments = cluster_questions(questions, min_cluster_size=15)
centroids = calculate_centroids(questions, embeddings, assignments)
df_agg = aggregate_data(questions, assignments, centroids)

# %%
generate_report(df_agg)
# Out:
# ================================================================================
# Total generated questions: 1114
# Number of clusters: 20
# Classified as noise: 273 (24.51%)
# ================================================================================
# |   cluster_id | centroid                                                                           |   cluster_size |
# |-------------:|:-----------------------------------------------------------------------------------|---------------:|
# |           10 | What specific phenomena or processes are being investigated in the study?          |            109 |
# |            8 | What methodology or techniques are employed in the study?                          |             99 |
# |            3 | What specific challenges or limitations does the study address or identify?        |             66 |
# |            9 | Which future research directions does the study recommend or outline?              |             59 |
# |            7 | What methodologies or techniques are discussed?                                    |             56 |
# |           18 | How do the findings relate to existing models or theories?                         |             49 |
# |           15 | What are the main findings of the study?                                           |             48 |
# |            2 | How do the findings affect the understanding of astronomical systems?              |             44 |
# |           12 | What specific variables or conditions are crucial in the study's findings?         |             44 |
# |            5 | What are the broader implications or potential applications of the findings?       |             38 |
# |            0 | What is the main focus of the study?                                               |             37 |
# |            4 | What are the main challenges or limitations identified?                            |             34 |
# |           13 | What is the primary focus or issue discussed?                                      |             29 |
# |           16 | What broader scientific implications or applications do the study's findings have? |             28 |
# |            6 | What comparisons are made within the study?                                        |             25 |
# |           11 | What key finding was highlighted?                                                  |             23 |
# |           14 | What detailed evidence or data is used to support the study's claims?              |             20 |
# |            1 | What is revealed about the central mass?                                           |             18 |
# |           17 | What broader context or field does the study contribute to or address?             |             15 |
#
# ================================================================================
# NOISE CLUSTER
# What comprehensive insights or breakthroughs does the study provide for the field?
# N = 273
# ================================================================================
# What is the primary subject of the document?
# What evidence or analysis does the document present?
# What future applications or innovative potential does the study suggest?
# How does the study contribute to ongoing debates or unresolved questions in the field?
# What additional data or analyses were included in the update?
# What is the primary finding?
# What is highlighted about a specific phenomenon?
# What comprehensive analysis or synthesis is discussed?
# What is the main topic discussed in the document?
# What is the key finding or conclusion in the document?
# ... 263 others ...
#
# ================================================================================
# What specific phenomena or processes are being investigated in the study?
# N = 109
# ================================================================================
# Is there a specific condition or case where differences are observed?
# What is the potential implication for the phenomenon?
# What factors contribute to observed phenomena?
# What notable results or observations are described?
# What unique characteristics or observations are noted?
# How does the investigated topic compare to other known classes or phenomena?
# What comprehensive insights does the study offer about the investigated phenomena?
# What key phenomenon does the study focus on?
# Which phenomena or mechanisms drive the processes observed in the study?
# What key phenomenon was observed?
# ... 99 others ...
#
# ================================================================================
# What methodology or techniques are employed in the study?
# N = 99
# ================================================================================
# What methodologies or tools does the research utilize?
# What specific data or techniques does the study employ?
# How does the research approach differ from conventional methods?
# What method or tool is prominently used in the study?
# How does the study's methodology or approach enhance its findings?
# Which specific method was utilized in the study?
# How does the study validate its methods across different scenarios?
# What specific methods or approaches does the study employ to gather data?
# Which dataset or target is prominently discussed?
# What method or measurement is used in the study?
# ... 89 others ...
#
# ================================================================================
# What specific challenges or limitations does the study address or identify?
# N = 66
# ================================================================================
# What problem or challenge does the research address?
# What are the main limitations or constraints acknowledged in the research?
# What challenges or limitations are acknowledged in the current study?
# What experimental limitations are acknowledged?
# What are the detailed challenges or limitations identified in the study?
# What challenges or limitations does the research identify in current models?
# What are the main challenges or limitations identified in the study?
# How does the study propose to address identified challenges or limitations?
# What inconsistencies or challenges are identified in the datasets?
# What theoretical or observational challenges are outlined in the study?
# ... 56 others ...
#
# ================================================================================
# Which future research directions does the study recommend or outline?
# N = 59
# ================================================================================
# What are the future research directions or questions posited?
# What suggestions or implications are made for future work?
# What future improvements or advancements are projected in the field?
# Which future research directions are suggested?
# What are potential future research directions suggested by the study?
# What specific recommendations or future research directions are suggested based on the findings?
# What potential future applications or extensions are suggested?
# How are future research directions or needs articulated?
# What specific applications or future research directions are suggested?
# What theoretical considerations are raised for further exploration?
# ... 49 others ...
#
# ================================================================================
# What methodologies or techniques are discussed?
# N = 56
# ================================================================================
# What key process or method is explored?
# How does the strategy or result perform in different scenarios?
# What methodology or approach is emphasized?
# What detailed explanation is provided about the methods used?
# What discussions on methodology or theory are presented?
# What innovative strategies or technology enable these discoveries?
# How does the method's efficacy compare to others?
# What advancements does the method have over traditional techniques?
# Which scientific technique or tool is involved?
# Which techniques are compatible with the main method?
# ... 46 others ...
#
# ================================================================================
# How do the findings relate to existing models or theories?
# N = 49
# ================================================================================
# How does the study contextually relate its results to previous models or theories?
# What specific models or theories are tested or addressed?
# How do the findings align with previously understood concepts or models?
# Which aspects of the studied phenomenon are model-dependent or compared to existing models?
# Which models or theories are compared or evaluated in the study?
# How do chosen models or theories impact the study's conclusions?
# How do the study's results relate to existing models or theories?
# How do the observations compare to standard theoretical models?
# Which findings challenge or confirm existing theories?
# How do the findings compare to previous theories or models?
# ... 39 others ...
#
# ================================================================================
# What are the main findings of the study?
# N = 48
# ================================================================================
# What are the two primary outcomes or findings?
# What are the detailed findings and comparisons made in the study?
# What is the overall evaluation or conclusion of the study?
# What is a significant conclusion or implication of the research?
# What suggestion does the study make based on the findings?
# What is the main outcome or finding of the study?
# What significant findings or results are highlighted in the study?
# What significant finding does the study confirm?
# What are the main results or findings of the study?
# What are the main findings or conclusions of the research?
# ... 38 others ...
#
# ================================================================================
# How do the findings affect the understanding of astronomical systems?
# N = 44
# ================================================================================
# Which astrophysical phenomenon is discussed?
# How does the study's context relate to broader astrophysical concepts or phenomena?
# Which astronomical object is primarily discussed?
# In what ways do cosmic interactions affect outcomes in the study?
# Which specific astronomical process or phenomenon is investigated?
# Which astronomical area does the study concern?
# How do the findings affect the understanding of astronomical systems?
# What detailed insights are provided on the physical properties of the astronomical system?
# What are the broader implications of the study for the field of astrophysics?
# How does the study's methodology contribute to the field of astrophysics?
# ... 34 others ...
#
# ================================================================================
# What specific variables or conditions are crucial in the study's findings?
# N = 44
# ================================================================================
# Which additional factors or needs are identified in the study?
# What parameter or aspect shows a notable change?
# What variables are indicated to have limited or significant impact?
# What are the two main factors or models described in the study?
# What specific conditions or parameters are critical to interpretations in the study?
# What specific role does a secondary factor play in the study?
# What key features or parameters are analyzed in the study?
# What are the dominant variables or parameters explored in this study?
# What changes in physical parameters result from the study's findings?
# Which specific parameters or variables were significant to the findings?
# ... 34 others ...
#
# ================================================================================
# What are the broader implications or potential applications of the findings?
# N = 38
# ================================================================================
# What are the implications of the key findings?
# What implications or applications might the findings suggest?
# What potential implications or challenges do the findings address?
# What are the implications of the main finding?
# What is the significance or implication of the main findings?
# What broader theoretical or practical implications do the results hold?
# What are the noteworthy conclusions drawn from the findings presented?
# What are the potential implications of the findings?
# What are the broader implications of the results for the field of study?
# What are the critical findings and their significance in terms of theory or application?
# ... 28 others ...
#
# ================================================================================
# What is the main focus of the study?
# N = 37
# ================================================================================
# What was the primary object of study?
# What is the primary focus of the study?
# What is the main focus of the study?
# What is the primary focus of the study?
# What is the primary focus of the study?
# What is the main focus of the study?
# What is the main focus of the study?
# What is the primary focus of the study?
# What is the primary focus of the research or discussion?
# What is the primary focus or finding of the study?
# ... 27 others ...
#
# ================================================================================
# What are the main challenges or limitations identified?
# N = 34
# ================================================================================
# What limitations or exceptions are noted?
# What specific scenarios demonstrate exceptions or alternative outcomes?
# What benefit or limitation is reported?
# What main challenges or issues are identified?
# What are the main challenges or issues discussed?
# What are the specific challenges or limitations encountered?
# Which specific challenges are addressed, and how are they approached?
# What are the main challenges or limitations identified?
# What are the primary challenges or complexities discussed?
# What are the main challenges or limitations mentioned?
# ... 24 others ...
#
# ================================================================================
# What is the primary focus or issue discussed?
# N = 29
# ================================================================================
# What is the primary focus or subject discussed?
# What key result is presented regarding the main focus?
# Which key concept is mentioned?
# What is the primary focus of the discussion?
# What are the specific factors affecting the main topic?
# What is the primary focus or issue discussed?
# What is the main achievement or finding?
# What is the main achievement and potential application?
# What key concept is addressed?
# What specific aspect of the topic is addressed?
# ... 19 others ...
#
# ================================================================================
# What broader scientific implications or applications do the study's findings have?
# N = 28
# ================================================================================
# What are the main scientific implications or applications of this study?
# What potential for future research does this study suggest?
# What are the implications of the study's findings for broader scientific understanding?
# What implications does the study have for future research or applications?
# What are the broader implications or applications of the study's findings?
# What are the implications of the study's findings?
# What are the broader implications of the study's findings for the field?
# What are the implications of the study's findings?
# What are the broader implications or future directions suggested by the study?
# What are the broader implications or theoretical contributions of the study?
# ... 18 others ...
#
# ================================================================================
# What comparisons are made within the study?
# N = 25
# ================================================================================
# What comparison is made between elements?
# What comparisons are made with existing models or data?
# What comparative analyses are performed, and with what results?
# What comparative analysis is drawn in the study?
# What comparative analysis is performed against existing data or methods?
# How are statistical measures or comparisons used in the study?
# What comparisons or relationships are established with previous studies or data?
# Which elements of the study are briefly compared or evaluated?
# What are some key comparisons or contrasts made within the study?
# What comparability does the study claim?
# ... 15 others ...
#
# ================================================================================
# What key finding was highlighted?
# N = 23
# ================================================================================
# What significant creation or effect is highlighted?
# Which key result or finding is highlighted?
# What key measurement or result is highlighted?
# What key finding is highlighted?
# What observation or finding is highlighted?
# What key method or comparison is highlighted?
# What is a key discovery or finding?
# What is a key finding or conclusion presented?
# What key comparison or finding is mentioned?
# What is a key numerical result or comparison?
# ... 13 others ...
#
# ================================================================================
# What detailed evidence or data is used to support the study's claims?
# N = 20
# ================================================================================
# How do the findings compare with previous studies or measurements?
# How are the results or findings substantiated within the study?
# What validation or evidence supports the study's findings?
# What supporting evidence or measurements are presented?
# What detailed evidence or data is used to support the study's claims?
# What specific data, observations, or theoretical frameworks support the conclusions?
# What numerical estimates or predictions support the findings?
# What specific experimental or observational evidence supports the claims?
# What specific measurements or data support the conclusions?
# What findings are consistent with previous estimates or studies?
# ... 10 others ...
#
# ================================================================================
# What is revealed about the central mass?
# N = 18
# ================================================================================
# What specific structural properties of the cluster are identified?
# What does the dark mass in the cluster potentially indicate?
# What details about the cluster's structure were discovered?
# What precise measurements of the cluster's orientation and distance are provided?
# What possibilities are suggested for the central mass?
# What are the results regarding the core?
# What is revealed about the central mass?
# What is the estimated mass of the central object?
# What inclination is observed in the model?
# What is the rotational velocity of the core?
# ... 8 others ...
#
# ================================================================================
# What broader context or field does the study contribute to or address?
# N = 15
# ================================================================================
# What are the broader scientific or theoretical contexts discussed in relation to the study?
# What overarching framework or paradigm underpins the study's approach?
# What is the broad topic or context of the research?
# How does the study's context contribute to the broader field?
# How does the paper propose to advance research or knowledge in the field?
# What broader context or background is provided on the research topic?
# What theoretical frameworks or concepts underpin the study's analysis?
# How does the study contextualize its findings within the broader field?
# How does the study impact or advance previous research?
# How do the study's specifics contribute to a deeper understanding of the subject matter?
# ... 5 others ...

# %%
df_agg.reset_index()[['cluster_id', 'centroid','cluster_size']] \
    .sort_values('cluster_size', ascending=False) \
    .to_csv('../data/annotations/questions/astro-ph-clusters-raw.csv', index=False)

# %% [markdown]
# ## qmsum generic

# %%
questions = []
questions += generate_questions('../output/qmsum-generic/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json', 'qmsum')
questions += generate_questions('../output/qmsum-generic/Mistral-7B-Instruct-v0.3/summaries/temperature0.3-0.json', 'qmsum')
questions += generate_questions('../output/qmsum-generic/gpt-4o-mini-2024-07-18/summaries/temperature0.3-0.json', 'qmsum')
# Out:
# Batch cost: $0.2373
# Save 294 questions to ../output/qmsum-generic/Meta-Llama-3.1-8B-Instruct/discord-qa-contrastive/questions.json
# Batch cost: $0.2178
# Save 300 questions to ../output/qmsum-generic/Mistral-7B-Instruct-v0.3/discord-qa-contrastive/questions.json
# Batch cost: $0.2364
# Save 284 questions to ../output/qmsum-generic/gpt-4o-mini-2024-07-18/discord-qa-contrastive/questions.json

# %%
embeddings, assignments = cluster_questions(questions, min_cluster_size=15)
centroids = calculate_centroids(questions, embeddings, assignments)
df_agg = aggregate_data(questions, assignments, centroids)

# %%
generate_report(df_agg)
# Out:
# ================================================================================
# Total generated questions: 878
# Number of clusters: 19
# Classified as noise: 293 (33.37%)
# ================================================================================
# |   cluster_id | centroid                                                                          |   cluster_size |
# |-------------:|:----------------------------------------------------------------------------------|---------------:|
# |           10 | Which aspects of the main topic were covered in the discussion?                   |             64 |
# |            4 | What main topic was discussed in the meeting?                                     |             50 |
# |            9 | Who are the participants and their roles discussed in the meeting?                |             44 |
# |            6 | Which design features were important in the discussion?                           |             44 |
# |           17 | What were the major outcomes or decisions made during the meeting?                |             42 |
# |           16 | What potential future steps or actions were planned in the meeting?               |             41 |
# |            5 | What methodologies or strategies were discussed?                                  |             37 |
# |            8 | Who were the key participants or roles involved in the meeting?                   |             35 |
# |           12 | What aspect of the project was primarily discussed?                               |             33 |
# |           15 | What are the identified challenges or concerns discussed?                         |             28 |
# |            2 | What were the main objectives or goals discussed in the meeting?                  |             27 |
# |            1 | What are the main topics discussed in the meeting?                                |             25 |
# |           13 | What specific issues or challenges were identified during the meeting?            |             25 |
# |            0 | What is the primary topic of the meeting?                                         |             23 |
# |           11 | What aspects of the project were evaluated?                                       |             18 |
# |           14 | What detailed strategies or solutions were proposed for the challenges discussed? |             18 |
# |            3 | What collaborative efforts or partnerships were discussed?                        |             16 |
# |            7 | What were the anticipated impacts or implications discussed?                      |             15 |
#
# ================================================================================
# NOISE CLUSTER
# What specific issues or projects were addressed during the meeting?
# N = 293
# ================================================================================
# Which specific project or initiative is being addressed?
# What is the goal or purpose of the discussion?
# What outcomes or conclusions are anticipated from the meeting?
# What external factors or contexts are considered in the discussions?
# What are the broader implications or impacts of the meeting discussions?
# How do different stakeholders view the proposals or issues discussed?
# What additional details about planned activities or logistics were shared?
# How were the discussed initiatives intended to be implemented or structured?
# What was the structure of the meeting and roles of attendees?
# What complexities or detailed considerations were analyzed at the meeting?
# ... 283 others ...
#
# ================================================================================
# Which aspects of the main topic were covered in the discussion?
# N = 64
# ================================================================================
# What are the key topics or issues discussed?
# What specific issues related to the main topic are addressed?
# How do funding concerns impact the discussed topics?
# What specific topics were covered in addition to the main topic?
# What areas or elements were focused on during the discussion?
# What were the critical responses or oppositions presented during the discussion?
# What complex or multi-faceted issues were addressed in depth?
# What significant issues or themes were discussed?
# What specific areas were raised during the discussion?
# What is the main topic of discussion?
# ... 54 others ...
#
# ================================================================================
# What main topic was discussed in the meeting?
# N = 50
# ================================================================================
# What was the main topic of the meeting?
# What was the main focus of the meeting?
# What were the comprehensive topics covered in the meeting?
# What key topics were discussed in the meeting?
# What was the main area of focus in the meeting?
# What was the main topic of the meeting?
# What core topics were covered in the meeting?
# Which major topics and actions were discussed in the meeting?
# What were the main points of discussion related to meeting logistics?
# What were the details and resolutions related to the upcoming conferences or meetings?
# ... 40 others ...
#
# ================================================================================
# Who are the participants and their roles discussed in the meeting?
# N = 44
# ================================================================================
# Who are the main participants or presenters?
# What roles do specific individuals or organizations play in the meeting?
# Which organizations or individuals are involved, and what are their roles?
# Who are the primary participants in the meeting?
# What are the roles and contributions of each team member or panelist?
# Who are the key participants involved?
# Who are the main participants or committees involved?
# Who are the key participants in the meeting?
# Which individuals or groups are mentioned in relation to upcoming events?
# What roles or professions were mentioned and their contributions to the project?
# ... 34 others ...
#
# ================================================================================
# Which design features were important in the discussion?
# N = 44
# ================================================================================
# What specific examples or applications were suggested to illustrate key concepts?
# What elements of the design are discussed and evaluated?
# What specific design features were evaluated or modified?
# What were the intricate details around the discussed design choices and their implications?
# What were the detailed topics or features discussed?
# What models or structures were discussed in detail?
# What specific design concepts or ideas were considered?
# What specific themes or styles were chosen for a conceptual design?
# What are the various designs or features considered?
# What are some of the key design features discussed?
# ... 34 others ...
#
# ================================================================================
# What were the major outcomes or decisions made during the meeting?
# N = 42
# ================================================================================
# Who provided feedback or suggestions during the meeting?
# What were the outcomes or agreements reached?
# What specific actions or decisions were made during the meeting?
# What major decisions or agreements were made?
# What compromises or trade-offs were decided upon?
# What specific outcomes or conclusions were reached during the meeting discussion?
# What were the primary factors influencing the decision-making during the meeting?
# What were the key outcomes or agreements from the meeting?
# What were the key points of feedback or evaluation given in the meeting?
# What were the main conclusions or action items from the meeting?
# ... 32 others ...
#
# ================================================================================
# What potential future steps or actions were planned in the meeting?
# N = 41
# ================================================================================
# What are the anticipated next steps or actions following the meeting?
# What were the next steps or actions decided upon by the committee?
# What significant decisions or plans were made during the meeting?
# What future steps or follow-ups were identified in the meeting?
# What are the next steps or actions decided upon in the meeting?
# What potential future steps or actions were planned in the meeting?
# What longer-term goals or plans were formulated?
# What were the main topics addressed during the meeting in terms of future plans?
# Which future steps or follow-up actions were proposed at the meeting?
# What specific actions or follow-ups were agreed upon during the meeting?
# ... 31 others ...
#
# ================================================================================
# What methodologies or strategies were discussed?
# N = 37
# ================================================================================
# What specific technologies or methods are discussed during the meeting?
# What detailed methods or tools are evaluated or chosen in the meeting?
# What specific topics or technical aspects were examined?
# What technical or methodological approaches were debated?
# What technology or field was discussed?
# What discussions took place around the effectiveness or shortcomings of existing systems?
# What specific methodologies or technologies were highlighted in the meeting discussions?
# What methodologies or approaches are being considered or discussed?
# What specific experiments or projects were presented or discussed?
# What methods or techniques are under consideration for improvement?
# ... 27 others ...
#
# ================================================================================
# Who were the key participants or roles involved in the meeting?
# N = 35
# ================================================================================
# Who are the notable participants in the meeting?
# Who were key participants in the meeting?
# Who were the prominent speakers or figures that contributed to the meeting?
# Who were the parties involved in the meeting and what topics were addressed?
# What roles do specific individuals play in the meeting discussion?
# Who were the key participants in the meeting?
# Which notable individuals contributed to the discussions?
# What specific roles did participants play in the meeting discussions?
# Which roles or actors were involved in the discussion?
# Which government was involved in the meeting discussion?
# ... 25 others ...
#
# ================================================================================
# What aspect of the project was primarily discussed?
# N = 33
# ================================================================================
# What general project or proposal was being discussed?
# What was the objective or aim of the discussed project?
# What were the intended outcomes or target audience of the project?
# What aspect of the project was primarily discussed?
# What were the main elements discussed in the project?
# What detailed steps or phases were part of the project's discussion?
# What were the main goals related to the discussed project?
# What were the significant strategies or approaches decided on for the project's execution?
# What were the detailed discussions or analyses related to project challenges and solutions?
# What significant projects or papers are under discussion?
# ... 23 others ...
#
# ================================================================================
# What are the identified challenges or concerns discussed?
# N = 28
# ================================================================================
# What are the concerns or challenges mentioned?
# What were the primary challenges or issues discussed?
# What key challenges are mentioned?
# What specific challenges or issues were identified in the project?
# What were some of the major concerns or challenges raised?
# What are the identified challenges or concerns discussed?
# Which specific challenges or risks are associated with the project?
# What challenges or concerns are mentioned?
# What specific challenge or issue was addressed?
# Which specific challenges or issues were identified during the discussion?
# ... 18 others ...
#
# ================================================================================
# What were the main objectives or goals discussed in the meeting?
# N = 27
# ================================================================================
# What are the key objectives or outcomes identified in the meeting?
# What is the main goal or objective of the meeting?
# How does the final decision align with the original goals or expectations?
# What are the goals or objectives mentioned in the summaries?
# What were the intended goals or outcomes mentioned in the meeting?
# What general objectives or goals were identified?
# What financial or numerical goals were established during the meeting?
# What are the main objectives or goals of the meeting?
# What are the objectives or goals discussed in the meeting?
# What are the key objectives and ideas discussed?
# ... 17 others ...
#
# ================================================================================
# What are the main topics discussed in the meeting?
# N = 25
# ================================================================================
# What are the main topics covered in the meeting?
# What are the detailed discussions or debates within the meeting?
# What are the key topics or subjects of the meeting?
# What are the main topics discussed in the meeting?
# What are the comprehensive topics and issues covered during the meeting?
# What is the main topic discussed in the meeting?
# What are the main topics discussed in the meeting?
# What are the main focus areas or components discussed in the meeting?
# What key aspects or features are discussed during the meeting?
# Which specific aspects of a project are typically addressed in a meeting?
# ... 15 others ...
#
# ================================================================================
# What specific issues or challenges were identified during the meeting?
# N = 25
# ================================================================================
# What concerns or challenges were identified during the meeting?
# What were some of the challenges identified in the meeting?
# What specific issues or challenges were identified during the meeting?
# Which challenges or limitations were identified during the meeting's discussion?
# What challenges or considerations are mentioned in the meeting discussion?
# How did the meeting address the challenges faced by certain groups or sectors?
# What are the key concerns discussed in the meeting?
# What challenges or issues were identified during the meeting?
# Which specific issues or challenges are mentioned in the meeting context?
# Which challenges were identified during the meeting?
# ... 15 others ...
#
# ================================================================================
# What is the primary topic of the meeting?
# N = 23
# ================================================================================
# What is the primary topic of the meeting?
# What is the main topic of the meeting?
# What is the main topic of the meeting?
# What is the focus area of the meeting?
# What is the main topic of the meeting?
# How is the primary subject of the meeting described?
# How are external perceptions of the meeting's topic described?
# What is the setting of the meeting?
# What is the main topic of the meeting?
# What is the overall context and purpose of the meeting?
# ... 13 others ...
#
# ================================================================================
# What aspects of the project were evaluated?
# N = 18
# ================================================================================
# What feedback was provided about the project process?
# What considerations or criteria were evaluated in the project discussion?
# What were the key criteria or metrics used for evaluation of the project?
# What evaluation or assessment was conducted?
# Which evaluation metrics or test data are discussed for the project's future?
# What aspects of the project were evaluated?
# How did the team approach prototype evaluation?
# Which specific features of a product were evaluated?
# How was progress on projects or designs evaluated?
# How were different elements of the project assessed?
# ... 8 others ...
#
# ================================================================================
# What detailed strategies or solutions were proposed for the challenges discussed?
# N = 18
# ================================================================================
# What strategies or solutions are proposed to address these issues?
# What specific strategies or solutions were proposed or debated?
# What potential solutions or strategies are proposed for the challenges discussed?
# What alternative approaches or options were considered in the discussion?
# What are the potential solutions or ideas proposed?
# What solutions or defenses are proposed in response to the concerns raised?
# Which specific implementation challenges and strategies are discussed?
# What are the anticipated challenges in implementing proposed changes or strategies discussed?
# What comprehensive strategies or frameworks were considered to address challenges?
# What detailed plans or steps were outlined for addressing identified challenges in the project?
# ... 8 others ...
#
# ================================================================================
# What collaborative efforts or partnerships were discussed?
# N = 16
# ================================================================================
# Which external collaborations or influences were discussed in the meetings?
# How did the participants approach coordination and collaboration efforts?
# What collaborations or external influences are acknowledged in the meeting?
# Which cross-functional or interdisciplinary collaborations were emphasized during the meeting?
# What opinions were expressed about teamwork?
# What additional external resources or collaborations were mentioned?
# What collaborations or external parties are involved?
# What collaborative efforts or multi-departmental strategies are discussed?
# What collaborative efforts or partnerships were discussed?
# What collaborative efforts or individual tasks were emphasized in the meeting?
# ... 6 others ...
#
# ================================================================================
# What were the anticipated impacts or implications discussed?
# N = 15
# ================================================================================
# What potential risks or unintended consequences were acknowledged?
# What is the broader impact discussed during the meeting?
# What implications or impacts are foreseen based on the meeting's findings or proposals?
# What potential impacts on staff or personnel were highlighted?
# What long-term outcomes or impacts were anticipated or planned for?
# What were the implications or expected impacts of the decisions taken?
# Were there any broader implications or future steps discussed?
# Which departments or sectors are involved or affected?
# Which specific concerns or consequences were explored?
# What were the anticipated impacts or implications discussed?
# ... 5 others ...

# %%
df_agg.reset_index()[['cluster_id', 'centroid','cluster_size']] \
    .sort_values('cluster_size', ascending=False) \
    .to_csv('../data/annotations/questions/qmsum-generic-clusters-raw.csv', index=False)

# %% [markdown]
# ## pubmed-sample

# %%
questions = []
questions += generate_questions('../output/pubmed-sample/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json', 'pubmed')
questions += generate_questions('../output/pubmed-sample/Mistral-7B-Instruct-v0.3/summaries/temperature0.3-0.json', 'pubmed')
questions += generate_questions('../output/pubmed-sample/gpt-4o-2024-08-06/summaries/temperature0.3-0.json', 'pubmed')
# Out:
# Load existing questions: ../output/pubmed-sample/Meta-Llama-3.1-8B-Instruct/discord-qa-contrastive/questions.json
# Load existing questions: ../output/pubmed-sample/Mistral-7B-Instruct-v0.3/discord-qa-contrastive/questions.json
# Batch cost: $0.5912
# Save 657 questions to ../output/pubmed-sample/gpt-4o-2024-08-06/discord-qa-contrastive/questions.json

# %%
embeddings, assignments = cluster_questions(questions, min_cluster_size=15)
centroids = calculate_centroids(questions, embeddings, assignments)
df_agg = aggregate_data(questions, assignments, centroids)

# %%
generate_report(df_agg)
# Out:
# ================================================================================
# Total generated questions: 2016
# Number of clusters: 38
# Classified as noise: 609 (30.21%)
# ================================================================================
# |   cluster_id | centroid                                                                                 |   cluster_size |
# |-------------:|:-----------------------------------------------------------------------------------------|---------------:|
# |           34 | What specific treatments were compared in the study?                                     |             67 |
# |           20 | What were the methods used in the study?                                                 |             63 |
# |           11 | What was the study design or setting of the trial?                                       |             58 |
# |           30 | What was the main finding regarding the intervention's efficacy?                         |             58 |
# |           17 | Which population is the study focused on?                                                |             53 |
# |            2 | What limitations or considerations are noted by the study?                               |             52 |
# |           14 | What implications or future recommendations did the study suggest based on its findings? |             51 |
# |           29 | What is the main outcome or effect observed?                                             |             51 |
# |            8 | What were the comparative results between intervention and control groups?               |             51 |
# |           23 | What specific metrics or outcomes were measured?                                         |             50 |
# |           19 | How were the participants or subjects of the study selected and divided?                 |             48 |
# |           28 | What are secondary outcomes noted in the study?                                          |             45 |
# |           36 | What was the main intervention used in the study?                                        |             44 |
# |           21 | What was the study design or methodology employed?                                       |             43 |
# |           32 | What effect does the intervention have on the main outcome?                              |             40 |
# |           10 | Which patient population is the study concerned with?                                    |             39 |
# |            5 | Which groups or comparisons are detailed in the study?                                   |             39 |
# |           15 | What are the broader implications or conclusions of the study?                           |             38 |
# |           16 | What is the main outcome of the study?                                                   |             38 |
# |           26 | What significant statistical results are reported?                                       |             38 |
# |            9 | What condition is being addressed in the study?                                          |             37 |
# |           13 | What is the main treatment or intervention being evaluated?                              |             36 |
# |           12 | What is the main intervention or treatment studied?                                      |             34 |
# |           18 | What is the participant demographic or characteristics in the study?                     |             33 |
# |            7 | What are the implications of the findings for clinical practice or future research?      |             31 |
# |           33 | What is the primary intervention being studied?                                          |             29 |
# |           27 | How does the intervention compare to the control or alternative treatments?              |             28 |
# |            1 | What is the main focus of the study?                                                     |             26 |
# |            0 | How long was the duration of the intervention or study?                                  |             26 |
# |           25 | What were the key findings or results of the study?                                      |             22 |
# |           22 | What are the specific outcomes measured in the study?                                    |             22 |
# |            4 | What are the main findings regarding efficacy and safety?                                |             22 |
# |           24 | What is the main finding of the study?                                                   |             21 |
# |            3 | What are the detailed findings regarding adverse events or side effects?                 |             21 |
# |           31 | What are the significant benefits of the intervention?                                   |             20 |
# |            6 | What are the specific biological markers influenced by the intervention?                 |             17 |
# |           35 | What methodology was used to assess the intervention's effectiveness?                    |             16 |
#
# ================================================================================
# NOISE CLUSTER
# What specific results were observed in the study outcomes?
# N = 609
# ================================================================================
# What are the underlying mechanisms or theories suggested for observed results or phenomena?
# What treatment or intervention was tested in the study?
# What comparison or benchmark was used against the treatment or intervention in the study?
# What primary benefit or effect was observed from the treatment?
# How was the study designed in terms of controls or randomization?
# What specific metrics or outcomes were measured in the study?
# What was the trial design and sample size of the study?
# What intervention is being studied?
# Which patient group is affected by the intervention?
# What was the measurable impact on patient health outcomes?
# ... 599 others ...
#
# ================================================================================
# What specific treatments were compared in the study?
# N = 67
# ================================================================================
# What was the relative magnitude of the treatment effects?
# What were the comparative measures of effectiveness between treatments?
# What were the notable differences in side effects or safety between treatment groups?
# What conclusions did the study reach about the efficacy of the treatment?
# Which drugs or interventions were compared in the study?
# What are the key benefits of one treatment over the other?
# Which dose or form of treatment showed superior results?
# What significant differences were noted between the treatments tested?
# Are there any notable pharmacological advantages of one treatment over the other?
# How did different doses of the treatments affect results or outcomes?
# ... 57 others ...
#
# ================================================================================
# What were the methods used in the study?
# N = 63
# ================================================================================
# What are the detailed procedures or protocols followed in the study?
# What methodology and controls were used in executing the study?
# What are the detailed methodology and protocols followed?
# What methodology or approach was used in the study?
# What specific methods and procedures were implemented?
# What methodology and outcomes did the study employ and observe over time?
# What specific techniques or analyses are used in the study?
# What was the primary methodology used in the study?
# What were the methodology details of the study?
# What are the detailed methodologies or procedures used in the study?
# ... 53 others ...
#
# ================================================================================
# What was the main finding regarding the intervention's efficacy?
# N = 58
# ================================================================================
# What is the primary finding of the study regarding the intervention?
# What was the study's purpose and what did it find regarding intervention outcomes?
# What strategies were employed and what results did they yield?
# What specific improvements were observed as a result of the intervention?
# What were the main findings regarding the intervention's effectiveness?
# What is a significant finding related to treatment efficacy?
# What were the main limitations or additional findings regarding the intervention's impact?
# What were the main findings regarding the intervention's impact?
# What specific aspect of health did the intervention affect?
# What is the study's main finding about the intervention?
# ... 48 others ...
#
# ================================================================================
# What was the study design or setting of the trial?
# N = 58
# ================================================================================
# What specific trial design and patient demography were involved in this study?
# What were the specific methods or approaches used in the trial?
# What was the trial's design and its conclusion?
# How did the trial design and its subsequent analysis reveal comparative results?
# What are the specific methodologies and controls used in the trial?
# What are the specific aims or endpoints of the trial?
# What was the main focus of the trial?
# Who were the participants involved in the trial?
# What was the design of the trial?
# What detailed methodology was used in conducting the trial?
# ... 48 others ...
#
# ================================================================================
# Which population is the study focused on?
# N = 53
# ================================================================================
# Who is the target population addressed in the study?
# Who is the target population for the intervention?
# Which population is primarily affected in the study?
# Who is the target population?
# Which demographic or population is targeted in the study?
# What population or group is the study focused on?
# Which population was targeted in the study?
# What was the target population involved in the study?
# Who is the target population or participants of the study?
# Which population is the study focused on?
# ... 43 others ...
#
# ================================================================================
# What limitations or considerations are noted by the study?
# N = 52
# ================================================================================
# How are study limitations or areas for further research addressed?
# What are the potential applications or future directions suggested?
# What are the specific components or areas of improvement mentioned?
# What are the limitations or areas lacking significant results?
# What limitations or future directions are suggested?
# What challenges or limitations were identified in the study?
# What challenges or barriers related to the intervention are identified?
# What were the key limitations or considerations acknowledged in the study?
# Were there any noted limitations or considerations for future research?
# What were the primary limitations or challenges identified in the study?
# ... 42 others ...
#
# ================================================================================
# What implications or future recommendations did the study suggest based on its findings?
# N = 51
# ================================================================================
# What implications or recommendations does the study suggest based on findings?
# What are the longer-term recommendations from the study?
# What are the broader recommendations for future research or practice?
# What are the practical implications or recommendations derived from the study?
# What specific recommendations or conclusions does the study make?
# What were the implications or recommendations for future research or practice?
# What are the implications or recommendations for future research?
# What was the proposed potential impact of the study's findings?
# What additional research or actions does the study suggest?
# What broader implications or recommendations were made by the study?
# ... 41 others ...
#
# ================================================================================
# What is the main outcome or effect observed?
# N = 51
# ================================================================================
# What is the main outcome or effect observed?
# What is the main outcome or result?
# What is the intended effect or outcome?
# What is the primary outcome or finding?
# What are the key findings related to the primary outcome?
# What is the primary effect observed?
# What other contextual details or prior phases are mentioned?
# What main positive or negative effect was observed?
# What is a key result related to the primary outcome?
# What was the main outcome observed?
# ... 41 others ...
#
# ================================================================================
# What were the comparative results between intervention and control groups?
# N = 51
# ================================================================================
# How does the intervention impact different groups or treatment conditions?
# What statistical or comparative data is provided about the intervention and control groups?
# What significant improvements were observed in the study group?
# What are notable differences between intervention groups?
# How does the intervention group compare to the control group?
# What comparison is being made between treatment and placebo groups?
# What comparisons or controls are included in the study?
# How was the control group compared to the intervention group in the study?
# What significant changes were noted in the intervention group?
# What improvements were observed specifically in the intervention group?
# ... 41 others ...
#
# ================================================================================
# What specific metrics or outcomes were measured?
# N = 50
# ================================================================================
# What measurement or outcome scale is mentioned?
# What specific indices or scales are used to measure outcomes or health improvements?
# What major statistical methods or endpoints were used in evaluating outcomes?
# What specific metrics or parameters were measured?
# What key components make up the scoring or assessment system?
# What detailed outcomes or scores were used to measure effectiveness?
# What metrics or scales were used to assess outcomes?
# What are the specific measurements or scales used in the study?
# Which specific measures or indices were reported?
# What specific metrics or rates were measured in the study?
# ... 40 others ...
#
# ================================================================================
# How were the participants or subjects of the study selected and divided?
# N = 48
# ================================================================================
# How were participants grouped or divided in the study?
# How were study participants selected and divided?
# How is the study structured or who are the participants?
# Who were the participants and how were they assigned to study groups?
# Who are the participants or subjects involved?
# How were participants selected and what methods were used in the study?
# What is the detailed methodology or criteria for participant selection?
# How were participants allocated in the trial and what was the duration?
# How were the participants assigned to different groups?
# Who are the participants in the study?
# ... 38 others ...
#
# ================================================================================
# What are secondary outcomes noted in the study?
# N = 45
# ================================================================================
# What are the long-term or secondary outcomes evaluated in this study?
# Which additional findings provide insights beyond the primary outcomes?
# What are the secondary outcomes or effects observed?
# What additional secondary outcomes are reported?
# What additional outcomes were observed in the study?
# What were the secondary outcomes or additional observations of the study?
# What primary outcome was affected?
# What additional outcomes were observed?
# What secondary outcomes or risk factors were highlighted?
# What secondary outcomes are hinted at?
# ... 35 others ...
#
# ================================================================================
# What was the main intervention used in the study?
# N = 44
# ================================================================================
# What specific intervention is compared to the standard or control in the study?
# What additional interventions or methods are combined in the study?
# What is the method or approach used in the study's intervention?
# What specific interventions/comparisons were analyzed in the study?
# What were the different phases or durations of the study's intervention?
# What combination of interventions was studied?
# Which intervention was tested in the study?
# What methodology does the study employ to assess the intervention's effect?
# Which interventions were compared in the study?
# What were the interventions compared in the trial?
# ... 34 others ...
#
# ================================================================================
# What was the study design or methodology employed?
# N = 43
# ================================================================================
# What methodology or research design is applied in the study?
# What was the specific study design and methodology used?
# What is the study design or methodology used?
# What methodology or study design was used in the research?
# What is the study's design or methodology?
# What is the design and scope of the study?
# What was the structure or design of the study?
# What is the study design and key result?
# What is the study design or methodology?
# What comprehensive details of the study design can be provided?
# ... 33 others ...
#
# ================================================================================
# What effect does the intervention have on the main outcome?
# N = 40
# ================================================================================
# What does the intervention affect in patients?
# What is the main outcome of the intervention?
# How does the intervention impact the primary outcome compared to control?
# What improvements or outcomes does the intervention aim to achieve?
# What is the observed outcome of the intervention?
# What effect does the intervention have on the main outcome?
# How does the intervention affect targeted outcomes?
# What is the primary outcome of the treatment?
# What primary outcome does the intervention seek to affect?
# What is the primary outcome of the intervention?
# ... 30 others ...
#
# ================================================================================
# Which patient population is the study concerned with?
# N = 39
# ================================================================================
# What specific patient group or demographic was involved in the study?
# Which patient population or condition is the study focused on?
# What patient population is involved?
# What specific patient groups or conditions are targeted?
# What specific patient group or condition is addressed?
# What subgroup does the study suggest might benefit more from a particular treatment?
# What specific condition or patient group was addressed?
# What patient population or condition is studied?
# Which patient group was studied?
# Which specific setting or patient population was involved in the study?
# ... 29 others ...
#
# ================================================================================
# Which groups or comparisons are detailed in the study?
# N = 39
# ================================================================================
# Which populations or subgroups showed notable differences?
# What comparative outcomes are reported between groups or conditions?
# What additional analyses or subgroup results are discussed?
# Were there any differences observed among subgroups or conditions?
# What is a notable comparison in the study?
# What are the two main comparators in the study?
# What were the comparison groups and the primary study endpoint?
# What were the different groups or conditions compared in the study?
# What is the comparison being made in the study?
# What detailed results were observed in each group?
# ... 29 others ...
#
# ================================================================================
# What are the broader implications or conclusions of the study?
# N = 38
# ================================================================================
# What was the overall interpretation of the study's findings and its impact on the field?
# What are the potential implications or conclusions drawn from the study?
# What is the implication of the study's findings?
# What are the broader implications or interpretations of the study results?
# What are the conclusions or implications of the study findings?
# What were the broader implications suggested by the study?
# What implication does the study suggest?
# What are suggested implications or applications of the study's findings?
# What are the potential applications of the study's findings?
# What conclusions or implications are drawn from the detailed results of the study?
# ... 28 others ...
#
# ================================================================================
# What is the main outcome of the study?
# N = 38
# ================================================================================
# What was the main outcome or finding of the study?
# What is the main finding or outcome of the study?
# What is the main outcome or result of the study?
# What is the primary outcome of the study?
# What is the main finding or outcome of the study?
# What is the primary outcome compared in the study?
# What main outcome does the study report?
# What is the main outcome or effect identified in the study?
# What is the main outcome of the study?
# What was the main outcome or aim of the study?
# ... 28 others ...
#
# ================================================================================
# What significant statistical results are reported?
# N = 38
# ================================================================================
# What detailed statistical or numerical results support the findings?
# What detailed statistical or numerical results were reported?
# What statistical significance or trends were reported?
# What statistical significance or confidence intervals were reported?
# What correlation was noted in the results?
# What statistical significance was reported in the study findings?
# What is being investigated or tested?
# What specific statistical outcomes or differences were highlighted in the results?
# What association or correlation is noted?
# What statistical significance or numerical change did the results indicate?
# ... 28 others ...
#
# ================================================================================
# What condition is being addressed in the study?
# N = 37
# ================================================================================
# What condition or disease was the focus of the study?
# What specific condition or treatment was examined?
# What aspect of health or medicine is being addressed?
# What specific conditions or diseases are considered in the study?
# What is the primary health condition or focus of the study?
# What condition or disease is being addressed in the study?
# What was the primary health risk or condition assessed?
# What specific condition or issue is addressed by the study?
# Which condition or treatment is being studied?
# What is the primary condition or disease being addressed?
# ... 27 others ...
#
# ================================================================================
# What is the main treatment or intervention being evaluated?
# N = 36
# ================================================================================
# What is the primary intervention or treatment being studied?
# Which therapeutic approach or test is evaluated?
# What is the intervention or treatment being studied?
# Which treatment or intervention is being assessed?
# What is the main intervention or treatment being studied?
# What treatment or intervention is being tested?
# Which methods or techniques are being used to address the issue?
# What is the primary intervention or treatment being studied?
# What intervention or treatment is being evaluated?
# What technique or intervention is being discussed?
# ... 26 others ...
#
# ================================================================================
# What is the main intervention or treatment studied?
# N = 34
# ================================================================================
# What is the primary intervention or treatment studied?
# What is the main intervention or method used?
# What is the main intervention or treatment studied?
# What is the primary intervention or treatment studied?
# What is the primary intervention or treatment and comparison?
# What is the primary intervention or treatment studied?
# What is the main intervention or treatment studied?
# What is the main intervention or treatment studied and its primary effect?
# What are the specifics of the intervention or treatment?
# What was the primary intervention or treatment studied?
# ... 24 others ...
#
# ================================================================================
# What is the participant demographic or characteristics in the study?
# N = 33
# ================================================================================
# What are the key demographic details or characteristics of the study participants?
# What were the specifics of the study's participant demographics or characteristics?
# How was the study population characterized?
# What specific participant demographics are included in the study?
# Which specific demographic or clinical characteristics defined the study sample?
# What were the specific group sizes and characteristics in the study?
# What specific demographic characteristics were included in the study sample?
# What were the baseline characteristics of the study participants?
# What were the specific demographics or characteristics of the study group?
# What are the participating groups or demographics involved in the study?
# ... 23 others ...
#
# ================================================================================
# What are the implications of the findings for clinical practice or future research?
# N = 31
# ================================================================================
# How did the results influence potential future clinical applications?
# What long-term implications could the findings have on therapeutic strategies?
# What recommendations did the study make for clinical practice?
# What are the clinical or practical implications of the study's findings?
# What are the broader implications for clinical practice based on the study?
# How might the results inform future clinical trials or practices?
# What future directions does the study suggest for clinical practice?
# What are the long-term or follow-up implications noted in the study?
# Are there any implications for patient care?
# How are the findings intended to impact current medical practices or policies?
# ... 21 others ...
#
# ================================================================================
# What is the primary intervention being studied?
# N = 29
# ================================================================================
# What are the additional agents or components in the intervention?
# What are the key components or elements included in the intervention?
# What key intervention was studied?
# What are the key components or elements of the intervention studied?
# What is the intervention being studied?
# What is the primary intervention and its broad effect?
# What is the primary intervention or variable studied?
# What is the primary intervention studied?
# What specific components are included in the intervention or program?
# What is the main intervention studied?
# ... 19 others ...
#
# ================================================================================
# How does the intervention compare to the control or alternative treatments?
# N = 28
# ================================================================================
# How does the intervention compare to the control in terms of effectiveness?
# What is the intervention compared to, if applicable?
# How does the effectiveness of the treatment compare to an alternative?
# How does the treatment compare to a control or another treatment?
# How does the intervention compare to a control or standard treatment?
# How does one method or intervention compare to another in effectiveness or safety?
# How does the intervention compare to other treatments or control groups?
# How does the intervention compare to the control?
# How does this treatment compare to existing treatments?
# How does the intervention compare to a control or alternative treatment?
# ... 18 others ...
#
# ================================================================================
# How long was the duration of the intervention or study?
# N = 26
# ================================================================================
# What is the duration or timeframe of the study or intervention?
# What was the scope or duration of the treatment in the study?
# What time intervals or duration of follow-up were utilized?
# What was the duration of the study and any follow-up period?
# What was the duration or scope of the treatment?
# What time frame does the study cover?
# How long was the treatment or follow-up period?
# How does the study define the timeframe for observed benefits?
# What is the duration of the intervention or follow-up period in the study?
# How many sessions or treatments were administered?
# ... 16 others ...
#
# ================================================================================
# What is the main focus of the study?
# N = 26
# ================================================================================
# Who or what is the main subject of the study?
# What is the purpose or objective of the study?
# What are the objectives or goals of the research project?
# What is the main hypothesis or goal of the study?
# What is the primary focus of the study?
# Who are the primary subjects?
# What is the primary focus of the study?
# What is the general focus of the study?
# What is the study's aim or hypothesis?
# What is the reasoning or hypothesis driving the study?
# ... 16 others ...
#
# ================================================================================
# What are the specific outcomes measured in the study?
# N = 22
# ================================================================================
# What does the study assess related to patient outcomes?
# How are patient outcomes quantified in the study?
# What specific outcomes or markers does the study measure?
# What is the specific outcome measured in the study?
# What are the primary outcomes measured in the study?
# How did the study assess the main outcomes?
# What main outcome was measured in the study?
# What comprehensive outcomes and metrics are assessed in the study?
# What are the specific outcomes measured in this study?
# What outcome is measured in the study?
# ... 12 others ...
#
# ================================================================================
# What are the main findings regarding efficacy and safety?
# N = 22
# ================================================================================
# What are the statistical results or relative risk reductions?
# What were the major outcomes or findings related to efficacy and safety?
# What are the notable effectiveness or outcome statistics?
# What are the main findings in terms of effectiveness or safety?
# What were the main findings in terms of effectiveness?
# What were the detailed results and comparative effectiveness?
# What are the safety or tolerability findings in the study?
# What detailed findings related to safety or efficacy were reported?
# What were the major findings in terms of effectiveness?
# What are the main findings regarding efficacy and safety?
# ... 12 others ...
#
# ================================================================================
# What were the key findings or results of the study?
# N = 22
# ================================================================================
# What significant results or findings are reported from the study?
# What was the size and statistical significance of the study's outcomes?
# What were the statistical or quantitative study findings?
# What were the primary findings or comparisons made?
# What are the significant findings or results of the study?
# What were the key findings or results of the study?
# What are the key findings of the study?
# What are the key findings or conclusions of the study?
# What were the detailed findings or results of the study?
# What are the main findings or conclusions of the study?
# ... 12 others ...
#
# ================================================================================
# What is the main finding of the study?
# N = 21
# ================================================================================
# What is the central finding of the study?
# What is the general conclusion derived from the study's results?
# What main conclusion is drawn from the study?
# What is the main finding of the study regarding effectiveness?
# What is the main finding of the study?
# What general conclusion can be drawn from the study?
# What is the primary finding of the study?
# What is a key finding of the research?
# What is the main finding of the study?
# What is the general conclusion of the study?
# ... 11 others ...
#
# ================================================================================
# What are the detailed findings regarding adverse events or side effects?
# N = 21
# ================================================================================
# What adverse effects or safety events were noted, if any?
# Is there any mention of adverse effects?
# Did any adverse events occur during the study?
# What is the major safety concern or side effect noted?
# What potential side effects or safety concerns are identified?
# What were the detailed findings regarding adverse reactions?
# What were the main findings regarding side effects or adverse events?
# What were the major safety findings or adverse events noted?
# Which adverse events or side effects are mentioned?
# What is noted regarding treatment safety or adverse events?
# ... 11 others ...
#
# ================================================================================
# What are the significant benefits of the intervention?
# N = 20
# ================================================================================
# What is the primary benefit or comparison result of the intervention?
# What primary benefit or effect does the intervention provide?
# What is the main benefit of the tested intervention?
# What notable effect does the intervention have?
# What is the primary benefit or effect of the intervention?
# Which additional specific effect or benefit is noted with the intervention?
# Why might this intervention be considered a viable alternative?
# What are the key benefits or drawbacks of the intervention?
# What primary benefit does the intervention show?
# What is the intended effect of the intervention?
# ... 10 others ...
#
# ================================================================================
# What are the specific biological markers influenced by the intervention?
# N = 17
# ================================================================================
# How does the intervention influence key biological markers or processes?
# What are the specific biological markers influenced by the intervention?
# What are the potential mechanisms or pathways involved?
# What are the specific molecular changes observed due to the intervention?
# What were the major biochemical or physiological markers assessed or regulated by the intervention?
# What were the primary and additional findings concerning physiological impacts?
# Is there any mention of mechanisms or physiological effects?
# What detailed changes in health markers are observed?
# What additional specifics are provided about BBB permeability changes?
# What are the specific effects on measured physiological parameters?
# ... 7 others ...
#
# ================================================================================
# What methodology was used to assess the intervention's effectiveness?
# N = 16
# ================================================================================
# What methods were used to evaluate the intervention's effectiveness?
# Which assessments or interventions were validated, and how?
# How is the effectiveness of the intervention being measured or assessed?
# What metrics were used to measure the effectiveness of the intervention?
# What methodology did the study use to evaluate the intervention's effectiveness?
# How are the effectiveness and safety of the intervention evaluated?
# How was the effectiveness of the intervention assessed?
# How did the study measure the effectiveness of the intervention?
# How was the effectiveness of the intervention measured?
# What key measurements were used to evaluate the effectiveness of the intervention?
# ... 6 others ...

# %%
df_agg.reset_index()[['cluster_id', 'centroid','cluster_size']] \
    .sort_values('cluster_size', ascending=False) \
    .to_csv('../data/annotations/questions/pubmed-sample-clusters-raw.csv', index=False)

# %% [markdown]
# ## cs-cl

# %%
questions = []
questions += generate_questions('../output/cs-cl/Meta-Llama-3.1-8B-Instruct/summaries/temperature0.3-0.json', 'cs-cl')
questions += generate_questions('../output/cs-cl/Mistral-7B-Instruct-v0.3/summaries/temperature0.3-0.json', 'cs-cl')
questions += generate_questions('../output/cs-cl/gpt-4o-2024-08-06/summaries/temperature0.3-0.json', 'cs-cl')
# Out:
# Load existing questions: ../output/cs-cl/Meta-Llama-3.1-8B-Instruct/discord-qa-contrastive/questions.json
# Load existing questions: ../output/cs-cl/Mistral-7B-Instruct-v0.3/discord-qa-contrastive/questions.json
# Load existing questions: ../output/cs-cl/gpt-4o-2024-08-06/discord-qa-contrastive/questions.json

# %%
embeddings, assignments = cluster_questions(questions, min_cluster_size=15)
centroids = calculate_centroids(questions, embeddings, assignments)
df_agg = aggregate_data(questions, assignments, centroids)

# %%
generate_report(df_agg)
# Out:
# ================================================================================
# Total generated questions: 1807
# Number of clusters: 36
# Classified as noise: 541 (29.94%)
# ================================================================================
# |   cluster_id | centroid                                                                    |   cluster_size |
# |-------------:|:----------------------------------------------------------------------------|---------------:|
# |           23 | What are the main approaches or techniques discussed in the document?       |             96 |
# |           12 | What recent advancements or innovations are highlighted in the document?    |             92 |
# |           30 | What improvements or contributions do the proposed methods make?            |             88 |
# |           15 | What main topic is the document addressing?                                 |             71 |
# |           11 | What are the new approaches or methods proposed to address the challenges?  |             55 |
# |            3 | What is the main focus of the research?                                     |             49 |
# |           33 | What is the main technique or method discussed?                             |             48 |
# |           28 | What limitations or challenges are identified in the existing methods?      |             43 |
# |            8 | How does the study relate to previous research in the field?                |             42 |
# |           16 | What are the broader implications or applications of the research findings? |             39 |
# |           31 | Which specific technologies or methodologies are mentioned?                 |             38 |
# |           25 | What is a prominent method mentioned for enhancing model effectiveness?     |             38 |
# |           22 | Which areas of improvement are discussed in relation to LLMs?               |             37 |
# |           19 | What future research directions does the document propose?                  |             37 |
# |            6 | Which datasets or models are discussed or evaluated in the document?        |             35 |
# |           29 | Which methods or techniques are compared or evaluated?                      |             32 |
# |            4 | What is the main focus of the study?                                        |             31 |
# |           27 | What are the main methods or techniques evaluated in the study?             |             31 |
# |            0 | What is the main focus of the document?                                     |             28 |
# |           18 | Which specific area of research does the document contribute to?            |             27 |
# |           14 | What challenge or gap is identified in the research?                        |             27 |
# |           10 | What challenges or problems does the document aim to address?               |             25 |
# |            7 | What are the challenges or limitations highlighted?                         |             25 |
# |            9 | What are the primary challenges discussed in the document?                  |             24 |
# |           21 | What significant results or conclusions does the document draw?             |             23 |
# |            1 | How have language models impacted specific tasks or applications?           |             22 |
# |            5 | Which benchmarks are considered in the study?                               |             22 |
# |            2 | What implications do the research findings have on future NLP developments? |             20 |
# |           17 | What domain or area does the research emphasize?                            |             19 |
# |           20 | Which previous works or studies are referenced?                             |             19 |
# |           13 | What challenge or problem does the research aim to address?                 |             19 |
# |           26 | What are the detailed methods or strategies employed in the research?       |             17 |
# |           32 | What specific frameworks or models are introduced or enhanced?              |             17 |
# |           24 | What challenges do the existing models face, and how are they addressed?    |             15 |
# |           34 | What novel approach or technique is proposed?                               |             15 |
#
# ================================================================================
# NOISE CLUSTER
# What unique approaches or hypotheses does the document propose?
# N = 541
# ================================================================================
# Which methods are highlighted in the research?
# Which techniques or models are mentioned as a focus in the research?
# What methodology is highlighted in the research?
# Which strategies and tools are employed to evaluate counterspeech?
# What types of models are utilized for counterspeech generation, and how are they evaluated?
# How does the proposed approach improve the alignment of graph and text embeddings?
# Which models or methods are primarily being evaluated or discussed?
# What findings or conclusions do the researchers draw from their work?
# What additional context or setting is provided for the study?
# What is identified as the link between discussed topics?
# ... 531 others ...
#
# ================================================================================
# What are the main approaches or techniques discussed in the document?
# N = 96
# ================================================================================
# Which specific techniques are compared or contrasted in the document?
# What methods are integrated within the proposed framework to enhance document understanding?
# What approach or method does the document propose or discuss?
# How do the authors propose to incorporate intermediate layer information?
# Which technology or concept is central to the document?
# What specific methods or technologies does the document discuss?
# How does the document describe current approaches within the discussed domain?
# What detailed methodologies or processes are explained for achieving the document's goals?
# What innovative approach is highlighted in the document?
# What methodologies are proposed or examined in the document?
# ... 86 others ...
#
# ================================================================================
# What recent advancements or innovations are highlighted in the document?
# N = 92
# ================================================================================
# What advancements or improvements are identified in the research?
# How do recent technologies shift research focus?
# What is the key advancement or method discussed?
# How are advancements applied in the industry?
# What advancement is highlighted in the study?
# What areas are being advanced in the research?
# What improvements in applications does the study discuss?
# What is the main advancement mentioned?
# What are the key enhancements or features in the research?
# Which areas or aspects are being improved by the research?
# ... 82 others ...
#
# ================================================================================
# What improvements or contributions do the proposed methods make?
# N = 88
# ================================================================================
# How does the proposed method differ from existing solutions?
# What are the intended outcomes of using the proposed method?
# What applications or contexts benefit from the discussed approaches?
# How do the proposed methods address known biases or issues?
# What are the distinguishing features of the proposed method?
# What specific problem does each method mentioned address?
# How does the proposed method differ from or improve upon existing methods?
# How are existing methods being extended or modified?
# How do the proposed methods compare or improve over previous methods?
# What problem or limitation does the technique address?
# ... 78 others ...
#
# ================================================================================
# What main topic is the document addressing?
# N = 71
# ================================================================================
# What aspect of NLP does the document address?
# What is the main focus, and how are tasks executed?
# What is the primary focus of the paper?
# What is the document's primary focus or research area?
# Which domain or application is involved?
# Which field is primarily discussed in the document?
# What type of data or documents are being discussed?
# Which area or application is the document focused on?
# What is the main topic of the document?
# What main topic is the document addressing?
# ... 61 others ...
#
# ================================================================================
# What are the new approaches or methods proposed to address the challenges?
# N = 55
# ================================================================================
# Which strategies or innovations does the research propose for overcoming the challenges?
# How is a specific problem or limitation being addressed?
# What are the challenges addressed by the proposed approach?
# Which detailed methodologies are proposed to address identified challenges?
# What innovations have been proposed to enhance watermark security in PLMs?
# What methodologies or approaches does the research employ to address the challenges?
# What methods or techniques are used to address the identified challenges?
# What specific strategies are introduced to address existing challenges?
# What solutions or innovations does the research propose for these challenges?
# What technique is proposed to address the problem?
# ... 45 others ...
#
# ================================================================================
# What is the main focus of the research?
# N = 49
# ================================================================================
# What is the main focus of the research discussed?
# What is the main contribution or focus of the research?
# What is the primary objective of the research?
# What primary topic does the research address?
# What is the main focus of the research?
# What is the primary focus of the research?
# How do researchers perceive the importance of the main topic?
# What is the primary focus of the research?
# What is the main focus of the research?
# What is the primary field of study?
# ... 39 others ...
#
# ================================================================================
# What is the main technique or method discussed?
# N = 48
# ================================================================================
# What method is primarily discussed?
# Which methods or techniques are mentioned as important?
# What is the main technique or method discussed?
# What is a key characteristic or feature of the technique?
# What specific methods or approaches are utilized in the technique?
# What categories or types of methods are involved in the technique?
# How does the technique differentiate between subtypes or categories within its field?
# What additional concepts or techniques are integrated into or compared with the main technique?
# What is the primary focus of the method discussed?
# What techniques or methods are explored?
# ... 38 others ...
#
# ================================================================================
# What limitations or challenges are identified in the existing methods?
# N = 43
# ================================================================================
# What are the limitations of current approaches discussed in the research?
# What challenges or limitations do current methods face, according to the research?
# What are the limitations of existing methods that the document identifies?
# Which challenges or limitations of existing methods are addressed?
# What issues or challenges are acknowledged in the current methods?
# What are detailed observations about the impact or limitations of current methods?
# What specific challenges do existing methods face with respect to performance and usability?
# What are the main limitations of current methods that the research aims to overcome?
# What are the major limitations of existing methods mentioned?
# Which limitations of existing methods are pointed out?
# ... 33 others ...
#
# ================================================================================
# How does the study relate to previous research in the field?
# N = 42
# ================================================================================
# How does the study compare AI-generated content?
# How does the study evaluate human likeness in generated content?
# What gaps or limitations in existing research does this study aim to fill?
# Why is the combination of human data and synthetic data relevant in the research?
# How do current findings compare to existing hypotheses or theories?
# How do the authors differentiate their research from previous studies?
# How does the study situate its contributions within the existing literature?
# How does the proposed approach build on previous studies?
# What previous findings does this study build upon or challenge?
# Which methodological advancements distinguish this study from related work?
# ... 32 others ...
#
# ================================================================================
# What are the broader implications or applications of the research findings?
# N = 39
# ================================================================================
# What are the broader implications or significance of the research findings?
# What are the broader implications or potential applications of the findings?
# What are the implications or potential applications of the research?
# What are the implications of the research findings?
# What are the broader impacts or potential applications of the study?
# What are the broader implications or potential applications of this research?
# What theoretical or empirical insights does the study provide?
# In what context or fields are these findings particularly relevant?
# What are the broader implications or significance of the research?
# What are the broader implications or applications of the research findings?
# ... 29 others ...
#
# ================================================================================
# What is a prominent method mentioned for enhancing model effectiveness?
# N = 38
# ================================================================================
# In what way does the research aim to improve model performance?
# What findings are presented regarding model evaluation or performance?
# Which key methodologies are proposed to enhance model performance and robustness?
# What new methods are introduced to improve the target models?
# What techniques are explored for understanding AI models?
# What are the primary techniques introduced for improving AI robustness?
# Which methods are explored for aligning models with human preferences?
# Which specific techniques or methods aim to improve model performance in the document's context?
# What recent methodologies are being considered for improving model performance?
# How do the methods improve the models' performance?
# ... 28 others ...
#
# ================================================================================
# Which specific technologies or methodologies are mentioned?
# N = 38
# ================================================================================
# What are the main components or techniques involved?
# What specific technologies or methods are utilized or tested?
# What technology or method is emphasized as being notable?
# Which technologies or methods are utilized in addressing the main topic?
# What previous works or existing technologies does the research build upon?
# Which methodologies or technologies are being proposed?
# What main technology or method is being explored?
# What auxiliary methods are explored alongside the main technology?
# Which tools or technologies are central to the research?
# Which technologies or methods are being explored in the document?
# ... 28 others ...
#
# ================================================================================
# What future research directions does the document propose?
# N = 37
# ================================================================================
# What are some areas of future research or open questions identified?
# What future directions or extended research does the document suggest?
# What future research directions or open questions are suggested?
# What further research or developments are suggested by the document?
# What future directions or research gaps does the document suggest?
# What future research directions does the document suggest?
# What potential future research directions are suggested?
# What future research directions or questions does the study identify?
# What future research directions or open questions does the document suggest?
# What potential areas of improvement or future research are suggested?
# ... 27 others ...
#
# ================================================================================
# Which areas of improvement are discussed in relation to LLMs?
# N = 37
# ================================================================================
# What enhancement method is discussed for multimodal embedding tasks?
# What unique alignment mechanism is introduced for graph and text embeddings?
# What methods integrate speech processing models with LLMs, and what tasks benefit?
# What challenges persist for LLMs in cross-domain reasoning tasks?
# How does LLM feedback contribute to improving overall question evaluation?
# What shortcomings in traditional automated metrics do LLM-based evaluations attempt to address?
# How do cognitive biases in LLMs parallel those found in humans according to recent studies?
# What capability of LLMs is discussed?
# What is the novelty in the proposed LLM evaluation methods?
# How do LLMs handle user feedback in human-robot interaction?
# ... 27 others ...
#
# ================================================================================
# Which datasets or models are discussed or evaluated in the document?
# N = 35
# ================================================================================
# Which existing datasets, models, or frameworks are mentioned?
# Which specific findings underscore the need for comprehensive datasets in video retrieval or similar NLP domains?
# Which specific datasets or models are critically evaluated or enhanced in the study?
# Which specific datasets or models are being utilized or proposed?
# Which datasets and models are highlighted in the research?
# What new datasets or experimental setups are introduced?
# Which specific dataset or model is introduced or analyzed?
# What unique features or attributes does a dataset or method offer?
# Which specific datasets or experimental setups are used for testing and evaluation?
# What datasets or methods are studied or compared?
# ... 25 others ...
#
# ================================================================================
# Which methods or techniques are compared or evaluated?
# N = 32
# ================================================================================
# How do proposed methods relate to existing evaluation techniques?
# Which methods or techniques are compared or evaluated?
# Which methods are used to evaluate or test the proposed solutions?
# How are the proposed solutions validated or tested?
# What specific tools or evaluators support the methodologies?
# What alternative or complementary methods are used in data and instruction selection?
# How is the effectiveness of the methods or approaches evaluated?
# What methodology is used to evaluate the efficacy of the new approach?
# Which existing works or approaches are compared against the proposed methods?
# What comparisons are made between existing and proposed methods?
# ... 22 others ...
#
# ================================================================================
# What are the main methods or techniques evaluated in the study?
# N = 31
# ================================================================================
# What are the key methods or approaches used in the study?
# Which method or concept is central to the study?
# Which key method or concept is examined?
# What are the key methodologies applied in this study?
# What specific techniques or models are mentioned in the study?
# What are the key methods or paradigms used for achieving the study's goals?
# How is the study's main approach implemented or structured?
# What detailed descriptions of methods and their impacts does the study provide?
# What specific methods are employed in the study?
# What specific operations or techniques are used to realize the study's goals?
# ... 21 others ...
#
# ================================================================================
# What is the main focus of the study?
# N = 31
# ================================================================================
# What is the main focus of the study?
# What is the detailed motivation or rationale for the study?
# What is the main focus of the study?
# What are the primary objectives of this study?
# Which specific sub-tasks or components are essential to the study's focus?
# What is the primary application or focus of the study?
# What is the primary focus of the study?
# What is the main focus of the study?
# What is the primary focus of the study in terms of problem-solving?
# What is the core focus of the study?
# ... 21 others ...
#
# ================================================================================
# What is the main focus of the document?
# N = 28
# ================================================================================
# What is the primary focus of the document?
# What is the primary focus of the document?
# What is the primary focus of the document?
# What is the primary focus of the document?
# What is the main focus of the document?
# What is the main focus of the document?
# What is the main focus of the document?
# What is the primary focus of the document?
# What is the main contribution or focus of the document?
# What is the primary focus of the document?
# ... 18 others ...
#
# ================================================================================
# Which specific area of research does the document contribute to?
# N = 27
# ================================================================================
# What is a keyword related to the document's research?
# How does the document contribute to existing research in its field?
# How does the document differentiate its focus from existing research?
# What progression or historical context is provided in the document?
# How does the document situate new contributions within the existing body of work?
# How do the document's contributions relate to handling biases or errors?
# How does the document place the research within the broader field?
# Which specific area of research does the document contribute to?
# How does the document situate its work within current research trends?
# How does the document describe the evolution or development of the topic?
# ... 17 others ...
#
# ================================================================================
# What challenge or gap is identified in the research?
# N = 27
# ================================================================================
# How does the research propose addressing the identified challenges?
# What are the identified gaps or unaddressed areas in the literature?
# How does the research propose to bridge existing research gaps?
# Which areas are identified as problematic in the research?
# How do the current limitations affect the research outcomes?
# What specific challenges do the findings aim to address?
# What key challenge is addressed in the research?
# What challenges and solutions are highlighted in the study?
# What challenges are identified in the research?
# What limitations or problems are being addressed by the research?
# ... 17 others ...
#
# ================================================================================
# What challenges or problems does the document aim to address?
# N = 25
# ================================================================================
# What challenges or problems does the document aim to address?
# What challenges or issues does the document address?
# What issue or challenge does the document address?
# What key issue or challenge does the document identify?
# What challenge or issue does the document address?
# What problem or need does the document aim to solve?
# Which primary problem does the document aim to address?
# What is the key issue addressed in the document?
# What specific problem does the document aim to solve?
# What key problem does the document address?
# ... 15 others ...
#
# ================================================================================
# What are the challenges or limitations highlighted?
# N = 25
# ================================================================================
# What potential challenges or risks are identified?
# What solutions or improvements are proposed to address these limitations?
# What is the main limitation or challenge identified?
# What key inefficiency or limitation is being addressed?
# What challenges or limitations are associated with the main technology?
# What is a notable downside or risk of the technology being addressed?
# What is the primary challenge or limitation?
# What are the challenges or limitations addressed?
# What are the challenges or limitations mentioned?
# What is the key limitation addressed?
# ... 15 others ...
#
# ================================================================================
# What are the primary challenges discussed in the document?
# N = 24
# ================================================================================
# What challenges are identified in the document?
# What is the main challenge discussed in the document?
# How does the document propose to address a major issue?
# Which specific challenges does the document identify in implementing the discussed solutions?
# What is the main challenge addressed?
# What challenges are identified in the document?
# What is a key challenge identified in the document?
# What is the primary challenge or issue discussed?
# What primary problem or challenge is being addressed?
# What specific problems or challenges are addressed in the document?
# ... 14 others ...
#
# ================================================================================
# What significant results or conclusions does the document draw?
# N = 23
# ================================================================================
# What is a key takeaway or conclusion from the document?
# What examples or studies does the document cite to support its claims?
# What are the implications of the findings presented in the document?
# What specific examples or case studies are provided to illustrate the document's claims?
# Which key insights or conclusions does the document draw from its analysis?
# What is a notable result or claim made in the document?
# What methodologies or experiments support the document's claims?
# What evidence or data is provided to support the document's claims or methods?
# What comprehensive analysis is provided in the document?
# What comprehensive evaluations or comparisons are presented in the document?
# ... 13 others ...
#
# ================================================================================
# Which benchmarks are considered in the study?
# N = 22
# ================================================================================
# How does the research address the limitations of existing benchmarks or methodologies?
# What are the new benchmarks or methods introduced in this research?
# How do the methods or benchmarks in this research compare to previous work in the field?
# Which datasets or benchmarks does the document mention for evaluating the proposed solutions?
# How do benchmarking initiatives contribute to the field discussed?
# What specific benchmarks or tools are introduced or discussed?
# What role do benchmarks and performance evaluations play in the study?
# Which benchmarks or evaluations are important in the study discussed?
# How do the proposed methods compare to existing benchmarks?
# What specific benchmarks or methods are highlighted in the document?
# ... 12 others ...
#
# ================================================================================
# How have language models impacted specific tasks or applications?
# N = 22
# ================================================================================
# What challenges associated with low-resource languages are acknowledged in the research?
# What challenge is addressed by language agents?
# What modules do language agents involve?
# What goal is achieved by integrating graph data with language models?
# What challenges do language agents encounter in real-world applications?
# What real-world capabilities do language agents extend to?
# What interpretability methods are suggested to improve language agent transparency?
# How have large language models previously been applied, and what have been their limitations?
# What are the computational challenges of the methods compared in language generation?
# How are diverse linguistic variations addressed in the proposed benchmarks?
# ... 12 others ...
#
# ================================================================================
# What implications do the research findings have on future NLP developments?
# N = 20
# ================================================================================
# What broader implications does the research suggest for the NLP field?
# What specific aspect of NLP is being explored?
# What implications do the research findings have on future NLP developments?
# How does the research contribute to the broader field of NLP?
# Which specific aspect of NLP is being improved?
# What implications do these findings have for future NLP research?
# What aspect of NLP is being explored?
# How do non-autoregressive models differ from autoregressive models in the study of NLP?
# In what ways do newer models address the limitations of traditional NLP modeling paradigms?
# Which specific problem in NLP is targeted by the research?
# ... 10 others ...
#
# ================================================================================
# What domain or area does the research emphasize?
# N = 19
# ================================================================================
# What field or domain does the research pertain to?
# What domain or application does the research predominantly focus on?
# Which specific tasks or domains show varied performance levels in the research?
# Which areas or communities are targeted by the research?
# What domain or area does the research emphasize?
# How does the research contribute to its field or domain?
# What broader impact does the research aim to achieve?
# What are the intended applications of the proposed research or analysis?
# What unique perspective or contribution does the research offer?
# What potential impact does the research have on its field of study?
# ... 9 others ...
#
# ================================================================================
# Which previous works or studies are referenced?
# N = 19
# ================================================================================
# What comprehensive background or related work is discussed?
# What are the main scientific contributions claimed by the authors?
# What foundational or early works are acknowledged in the research?
# Which past research works or studies are referenced?
# Who are the key contributors or researchers mentioned?
# What are the major strengths or contributions highlighted?
# What historical or foundational work is referred to or built upon?
# What previous work or related studies does the document reference?
# Which concurrent works are mentioned, and what do they contribute?
# What additional related works or references are noted in the document?
# ... 9 others ...
#
# ================================================================================
# What challenge or problem does the research aim to address?
# N = 19
# ================================================================================
# What challenge or problem does the research aim to address?
# What specific aspect or problem is being addressed in the research?
# How do the researchers aim to address the problem or achieve their objectives?
# What specific aspects of the model or task does the research aim to improve or refine?
# What issues does the research aim to resolve?
# How does the research approach the problem or challenge identified?
# What specific problem does the research aim to solve?
# What specific aspects of the problem do the researchers focus on understanding or improving?
# How does the research integrate different knowledge types or structures to address challenges?
# What problem or challenge does the research address?
# ... 9 others ...
#
# ================================================================================
# What are the detailed methods or strategies employed in the research?
# N = 17
# ================================================================================
# What specific experimental design or methodology was employed to achieve the research goals?
# What are the key components or techniques used in the research?
# What are the main research tasks or methods involved?
# What are the key components or methods proposed in the research?
# What comprehensive methods or approaches are detailed in the research?
# What specific elements are integrated into the research model or approach?
# What specific methodologies or techniques are employed to achieve research objectives?
# What are the methodological components or steps detailed in the research?
# What are the key methods or approaches discussed in the research?
# Which methodologies or techniques are explored in the research?
# ... 7 others ...
#
# ================================================================================
# What specific frameworks or models are introduced or enhanced?
# N = 17
# ================================================================================
# What specific frameworks or models are introduced or enhanced?
# What comprehensive framework or taxonomy is established or discussed?
# Which specific models or series are mentioned?
# Which existing frameworks does the study build upon?
# What type of models does the document focus on?
# Which specific models or frameworks are compared or discussed in the research?
# What existing frameworks or models are referenced in relation to advancements?
# What are the limitations of existing frameworks addressed by new models?
# Which specific models or frameworks are referenced, and what are their roles?
# Which other models or frameworks are mentioned?
# ... 7 others ...
#
# ================================================================================
# What challenges do the existing models face, and how are they addressed?
# N = 15
# ================================================================================
# What specific problem with existing models is being targeted in the research?
# What challenges do the existing models face, and how are they addressed?
# What are the limitations of the current models discussed?
# What are the limitations and prospects of the models discussed?
# Which previous models and their capabilities are critiqued or built upon?
# How do recent models address the limitations of prior approaches?
# What specific architectural or systemic changes are proposed to address model deficiencies?
# How do new models aim to overcome existing limitations?
# What are the limitations of current models, and how does this research contribute to addressing these limitations?
# What are the specific inadequacies of current models according to the document?
# ... 5 others ...
#
# ================================================================================
# What novel approach or technique is proposed?
# N = 15
# ================================================================================
# What novel approach or technique is proposed?
# What are the detailed components and processes of the proposed approach?
# What is the innovative approach or method discussed?
# What are the key components or techniques of the proposed approach?
# Which novel strategies or algorithms are emphasized in the research?
# What is the proposed new approach or method?
# What is the proposed solution or method introduced in the research?
# What is a proposed solution or method introduced?
# What is the innovative approach or method introduced?
# What is the focus of the novel algorithm or approach?
# ... 5 others ...

# %%
df_agg.to_json('../data/annotations/questions/cs-cl-clusters-raw.json', orient='records')
df_agg.reset_index()[['cluster_id', 'centroid','cluster_size']].sort_values('cluster_size', ascending=False).to_csv('../data/annotations/questions/cs-cl-clusters-raw.csv', index=False)

# %% [markdown]
# # Convert manual annotations into standard format

# %%
df = pd.read_excel('../data/annotations/questions/pubmed-sample-clusters-manual.xlsx', sheet_name='clustered')
df = df[df['selected'] == 'x']
df = df[['cluster_id', 'centroid', 'group_id', 'group_name']]
df.to_json('../output/pubmed-sample/discord_questions.json', orient='records', indent=4)
display(df)
# Out:
#     cluster_id                                           centroid  group_id  \
# 1            1               What is the main focus of the study?         1
# 3           10  Which patient population is the study concerne...         2
# 4            9    What condition is being addressed in the study?         3
# 5           18  What is the participant demographic or charact...         4
# 6           36  What was the main intervention used in the study?         5
# 10          31  What are the significant benefits of the inter...         6
# 11           6  What are the specific biological markers influ...         7
# 12          34  What specific treatments were compared in the ...         8
# 14          23   What specific metrics or outcomes were measured?         9
# 16          28    What are secondary outcomes noted in the study?        10
# 17          11  What was the study design or setting of the tr...        11
# 19          20           What were the methods used in the study?        12
# 21          19  How were the participants or subjects of the s...        13
# 22           0  How long was the duration of the intervention ...        14
# 23          29       What is the main outcome or effect observed?        15
# 29           4  What are the main findings regarding efficacy ...        16
# 30          26  What significant statistical results are repor...        17
# 31           3  What are the detailed findings regarding adver...        18
# 32           8  What were the comparative results between inte...        19
# 36          14  What implications or future recommendations di...        20
# 37           2  What limitations or considerations are noted b...        21
#
#                                 group_name
# 1                                    Topic
# 3                               Population
# 4                  Population -- Condition
# 5               Population -- demographics
# 6                             Intervention
# 10                Intervention -- benefits
# 11              Intervention -- biomarkers
# 12                             Comparators
# 14                                Outcomes
# 16                   Outcomes -- Secondary
# 17                       Design -- general
# 19                       Design -- methods
# 21            Design -- selection+grouping
# 22                      Design -- duration
# 23                         Results -- main
# 29             Result -- efficacy + safety
# 30                  Result -- significance
# 31  Results -- adverse events/side-effects
# 32                   Results -- comparison
# 36              Discussion -- implications
# 37               Discussion -- limitations

# %%
df = pd.read_excel('../data/annotations/questions/cs-cl-clusters-manual.xlsx', sheet_name='clustered')
df = df[df['selected'] == 'x']
df = df[['cluster_id', 'centroid', 'group_id', 'group_name']]
df.to_json('../output/cs-cl/discord_questions.json', orient='records', indent=4)
display(df)
# Out:
#     cluster_id                                           centroid  group_id  \
# 1           15        What main topic is the document addressing?         1
# 6           23  What are the main approaches or techniques dis...         2
# 9           12  What recent advancements or innovations are hi...         3
# 10           8  How does the study relate to previous research...         4
# 12          20    Which previous works or studies are referenced?         5
# 13          25  What is a prominent method mentioned for enhan...         6
# 15          14  What challenge or gap is identified in the res...         7
# 21          30  What improvements or contributions do the prop...         8
# 22          11  What are the new approaches or methods propose...         9
# 28          27  What are the main methods or techniques evalua...        10
# 29           5      Which benchmarks are considered in the study?        11
# 30          16  What are the broader implications or applicati...        12
# 32          19  What future research directions does the docum...        13
# 33          21  What significant results or conclusions does t...        14
#
#                        group_name
# 1                      Main topic
# 6                 Main techniques
# 9                 Recent advances
# 10  Relate to prior -- comparison
# 12  Relate to prior -- references
# 13                   Current SOTA
# 15           Existing limitations
# 21      Proposal -- contributions
# 22             Proposal -- method
# 28           Evaluation - methods
# 29              Evaluation - data
# 30         Implications of result
# 32              Future directions
# 33                    Conclusions

# %%
df = pd.read_excel('../data/annotations/questions/astro-ph-clusters-manual.xlsx', sheet_name='clustered')
df = df[df['selected'] == 'x']
df = df[['cluster_id', 'centroid', 'group_id', 'group_name']]
df.to_json('../output/astro-ph/discord_questions.json', orient='records', indent=4)
display(df)
# Out:
#     cluster_id                                           centroid  group_id  \
# 1            0               What is the main focus of the study?         1
# 3           10  What specific phenomena or processes are being...         2
# 4           17  What broader context or field does the study c...         3
# 5            3  What specific challenges or limitations does t...         4
# 7            8  What methodology or techniques are employed in...         5
# 9            6        What comparisons are made within the study?         6
# 10          15           What are the main findings of the study?         7
# 12          14  What detailed evidence or data is used to supp...         8
# 13          12  What specific variables or conditions are cruc...         9
# 14          18  How do the findings relate to existing models ...        10
# 15           2  How do the findings affect the understanding o...        11
# 16           5  What are the broader implications or potential...        12
# 18           9  Which future research directions does the stud...        13
#
#                           group_name
# 1                       Topic - main
# 3        Topic - phenomena processes
# 4                   Topic -- context
# 5         Challenges and limitations
# 7                             Method
# 9              Method -- comparisons
# 10                Results -- overall
# 12               Results -- evidence
# 13  Results -- parameters conditions
# 14   Discussion -- existing theories
# 15       Discussion -- understanding
# 16        Discussion -- implications
# 18                       Future work

# %%
df = pd.read_excel('../data/annotations/questions/qmsum-generic-clusters-manual.xlsx', sheet_name='clustered')
df = df[df['selected'] == 'x']
df = df[['cluster_id', 'centroid', 'group_id', 'group_name']]
df.to_json('../output/qmsum-generic/discord_questions.json', orient='records', indent=4)
display(df)
# Out:
#     cluster_id                                           centroid  group_id  \
# 1            9  Who are the participants and their roles discu...         1
# 3            4      What main topic was discussed in the meeting?         2
# 6            2  What were the main objectives or goals discuss...         3
# 7           10  Which aspects of the main topic were covered i...         4
# 9           15  What are the identified challenges or concerns...         5
# 11          14  What detailed strategies or solutions were pro...         6
# 12           7  What were the anticipated impacts or implicati...         7
# 13          17  What were the major outcomes or decisions made...         8
# 14           3  What collaborative efforts or partnerships wer...         9
# 15          16  What potential future steps or actions were pl...        10
#
#                         group_name
# 1            Participants -- roles
# 3                    Topic -- main
# 6                   Topic -- goals
# 7                 Topic -- aspects
# 9         Discussion -- challenges
# 11         Discussion -- solutions
# 12  Discussion -- solution impacts
# 13           Outcomes -- decisions
# 14      Outcomes -- collaborations
# 15             Outcomes -- actions
